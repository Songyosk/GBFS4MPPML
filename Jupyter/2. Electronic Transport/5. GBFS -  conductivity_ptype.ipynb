# %% [markdown]
# ### Load data

# %%
import pandas as pd
import numpy as np
import joblib
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from lightgbm.sklearn import LGBMRegressor

# %%
# Load dataset 
df = joblib.load('ricci_boltztrap_mp_tabular_merged_with_NaN_v2_ptype_.pkl')

# Define features and target variable
features = joblib.load('features_v2.pkl')
print('No. of features', len(features))

df.head()
# Out:
# No. of features 2497
#            minimum_oxidation_state  maximum_oxidation_state  \
# mp-1992                        0.0                      0.0
# mp-27502                       0.0                      0.0
# mp-770629                      0.0                      0.0
# mp-27202                       0.0                      0.0
# mp-559608                      0.0                      0.0
#
#            range_oxidation_state  std_dev_oxidation_state  compound_possible  \
# mp-1992                      0.0                      0.0                  0
# mp-27502                     0.0                      0.0                  1
# mp-770629                    0.0                      0.0                  1
# mp-27202                     0.0                      0.0                  0
# mp-559608                    0.0                      0.0                  1
#
#            max_ionic_char  avg_ionic_char  avg_anion_electron_affinity  \
# mp-1992          0.190712        0.044698                          0.0
# mp-27502         0.088829        0.016742                          0.0
# mp-770629        0.779730        0.171021                          0.0
# mp-27202         0.070306        0.004246                          0.0
# mp-559608        0.820234        0.145225                          0.0
#
#            minimum_EN_difference  maximum_EN_difference  ...  κₑᵉ.n.T [K]  \
# mp-1992                      0.0                    0.0  ...        100.0
# mp-27502                     0.0                    0.0  ...        100.0
# mp-770629                    0.0                    0.0  ...        100.0
# mp-27202                     0.0                    0.0  ...        600.0
# mp-559608                    0.0                    0.0  ...        100.0
#
#            κₑᵉ.n.c [cm⁻³]  mₑᶜ.p.ε̄ [mₑ]  mₑᶜ.p.ε₁ [mₑ]  mₑᶜ.p.ε₂ [mₑ]  \
# mp-1992      1.000000e+16            NaN            NaN            NaN
# mp-27502     1.000000e+16       9.948649       3.481600       5.835956
# mp-770629    1.000000e+16      10.016446       7.157813       8.633919
# mp-27202     1.000000e+16      25.742400      17.822069      20.141565
# mp-559608    1.000000e+16      91.371212      61.389242      61.389279
#
#            mₑᶜ.p.ε₃ [mₑ]  mₑᶜ.n.ε̄ [mₑ]  mₑᶜ.n.ε₁ [mₑ]  mₑᶜ.n.ε₂ [mₑ]  \
# mp-1992              NaN            NaN            NaN            NaN
# mp-27502       20.528390       0.990398       0.581862       1.084788
# mp-770629      14.257605       3.746585       1.077907       4.539832
# mp-27202       39.263564      19.824545      15.836995      18.160493
# mp-559608     151.335114       0.492688       0.485241       0.485241
#
#            mₑᶜ.n.ε₃ [mₑ]
# mp-1992              NaN
# mp-27502        1.304544
# mp-770629       5.622017
# mp-27202       25.476146
# mp-559608       0.507582
#
# [5 rows x 2540 columns]

# %%
target = 'p_conductivity' #'κₑ.p [W/K/m/s]' #Average eigenvalue of electrical thermal conductivity with hole concentration of 10^-18 carriers/cm^-3 (p-type) at 300K, in [W/K/m/s].

print(target)
print('Max value:', df[target].max())
print('Min value:', df[target].min())
# Out:
# p_conductivity
# Max value: 9999340663213412.0
# Min value: 201.14715833713612

# %% [markdown]
# ### Split & Scale Features

# %%
# !cd
# Out:
# c:\Users\songy\OneDrive\Documents\GBSFS4MPP_local\new_properties\6. ricci_boltztrap_mp_tabular (done)

# %%
# Split dataset
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)

# %%
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'

# Save unscaled data
joblib.dump(df_train, path_to_save + 'df_train_' + target + '.pkl')
joblib.dump(df_test, path_to_save + 'df_test_' + target + '.pkl')
# Out:
# ['C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/p_conductivity_results/df_test_p_conductivity.pkl']

# %%
# Scale the features
scaling = MinMaxScaler(feature_range=(0, 1))

df_train[features] = pd.DataFrame(
                                    scaling.fit_transform(df_train[features].values),
                                    columns=df_train[features].columns,
                                    index=df_train[features].index
                                )
                                
                                
# Create pandas.Dataframe of scaled test set using scaler as defined using training set
df_test[features] = pd.DataFrame(
                                    scaling.transform(df_test[features].values),
                                    columns=df_test[features].columns,
                                    index=df_test[features].index
                                )
# Out:
# c:\Users\songy\miniconda3\envs\gbfs\lib\site-packages\pandas\core\frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# c:\Users\songy\miniconda3\envs\gbfs\lib\site-packages\pandas\core\frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# Save 
joblib.dump(df_train, path_to_save + 'df_train_' + target + '_scaled.pkl')
joblib.dump(df_test, path_to_save + 'df_test_' + target + '_scaled.pkl')
# Out:
# ['C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/p_conductivity_results/df_test_p_conductivity_scaled.pkl']

# %% [markdown]
# #### GBFS

# %%
import sys
sys.path.insert(1, 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties')

import GBFS as gb

import joblib
import pandas as pd
import numpy as np

# %%
# Target
target = 'p_conductivity'

# Path to training data
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'
path_to_file = path_to_save + 'df_train_' + target + '_scaled.pkl'

# Either a list or saved file
features = path + 'features_v2.pkl'

problem = 'regression'

# %%
# Initialization 
FS = gb.GBFS(
            path_to_file = path_to_file, 
            path_to_save = path_to_save, 
            target = target,
            features = features,
            oversampled_it = False, 
            problem = problem
            )
# Out:
# Name of target column:  p_conductivity
# No. of exploratory features:  2497

# %%
# Conduct grid search to perform preliminary scan of the hyperparameter space & retrieve a trained model
FS.run(
        boosting_method = 'lightGBM', 
        cv_folds = 10
        )
# Out:
# Model employed:  lightGBM
# Total no. of permutations: 18
#
#
#    (1 of 18)  Attempt:  [('n_estimators', 100), ('learning_rate', 0.1), ('num_leaves', 30)]
#    No. of rows in the training set: 30441
#    Metric score:  -279781548105561895980333268992.00000
#    [*** Current optimal Hyperparameters ***]
# Finished loading model, total used 100 iterations
#
#
#    (2 of 18)  Attempt:  [('n_estimators', 100), ('learning_rate', 0.1), ('num_leaves', 40)]
#    No. of rows in the training set: 30441
#    Metric score:  -281947346834388637110350381056.00000
#
#
#    (3 of 18)  Attempt:  [('n_estimators', 100), ('learning_rate', 0.1), ('num_leaves', 50)]
#    No. of rows in the training set: 30441
#    Metric score:  -318923436136754655458964275200.00000
#
#
#    (4 of 18)  Attempt:  [('n_estimators', 100), ('learning_rate', 0.2), ('num_leaves', 30)]
#    No. of rows in the training set: 30441
#    Metric score:  -341270497204340892518800424960.00000
#
#
#    (5 of 18)  Attempt:  [('n_estimators', 100), ('learning_rate', 0.2), ('num_leaves', 40)]
#    No. of rows in the training set: 30441
#    Metric score:  -406428727107770863327480119296.00000
#
#
#    (6 of 18)  Attempt:  [('n_estimators', 100), ('learning_rate', 0.2), ('num_leaves', 50)]
#    No. of rows in the training set: 30441
#    Metric score:  -319045265626546141937486790656.00000
#
#
#    (7 of 18)  Attempt:  [('n_estimators', 300), ('learning_rate', 0.1), ('num_leaves', 30)]
#    No. of rows in the training set: 30441
#    Metric score:  -309508067802834244916251459584.00000
#
#
#    (8 of 18)  Attempt:  [('n_estimators', 300), ('learning_rate', 0.1), ('num_leaves', 40)]
#    No. of rows in the training set: 30441
#    Metric score:  -261376158959808600382591991808.00000
#    [*** Current optimal Hyperparameters ***]
# Finished loading model, total used 300 iterations
#
#
#    (9 of 18)  Attempt:  [('n_estimators', 300), ('learning_rate', 0.1), ('num_leaves', 50)]
#    No. of rows in the training set: 30441
#    Metric score:  -241510839701777741563689959424.00000
#    [*** Current optimal Hyperparameters ***]
# Finished loading model, total used 300 iterations
#
#
#    (10 of 18)  Attempt:  [('n_estimators', 300), ('learning_rate', 0.2), ('num_leaves', 30)]
#    No. of rows in the training set: 30441
#    Metric score:  -360445826386463736579022127104.00000
#
#
#    (11 of 18)  Attempt:  [('n_estimators', 300), ('learning_rate', 0.2), ('num_leaves', 40)]
#    No. of rows in the training set: 30441
#    Metric score:  -312202773903980685308257632256.00000
#
#
#    (12 of 18)  Attempt:  [('n_estimators', 300), ('learning_rate', 0.2), ('num_leaves', 50)]
#    No. of rows in the training set: 30441
#    Metric score:  -374951687368783740696885460992.00000
#
#
#    (13 of 18)  Attempt:  [('n_estimators', 500), ('learning_rate', 0.1), ('num_leaves', 30)]
#    No. of rows in the training set: 30441
#    Metric score:  -289279096825870233876960378880.00000
#
#
#    (14 of 18)  Attempt:  [('n_estimators', 500), ('learning_rate', 0.1), ('num_leaves', 40)]
#    No. of rows in the training set: 30441
#    Metric score:  -284214011038457528360332427264.00000
#
#
#    (15 of 18)  Attempt:  [('n_estimators', 500), ('learning_rate', 0.1), ('num_leaves', 50)]
#    No. of rows in the training set: 30441
#    Metric score:  -261599575443505398843581661184.00000
#
#
#    (16 of 18)  Attempt:  [('n_estimators', 500), ('learning_rate', 0.2), ('num_leaves', 30)]
#    No. of rows in the training set: 30441
#    Metric score:  -388348602493727354853225660416.00000
#
#
#    (17 of 18)  Attempt:  [('n_estimators', 500), ('learning_rate', 0.2), ('num_leaves', 40)]
#    No. of rows in the training set: 30441
#    Metric score:  -276020066100593613771561238528.00000
#
#
#    (18 of 18)  Attempt:  [('n_estimators', 500), ('learning_rate', 0.2), ('num_leaves', 50)]
#    No. of rows in the training set: 30441
#    Metric score:  -452495374571291312523992629248.00000
#
#  Model saved as: model_from_GBFS_p_conductivity.pkl
# LGBMRegressor(importance_type='gain', n_estimators=300, num_leaves=50,
#               objective='regression')

# %%
# Obtain feature relevance score
FS.feature_relevance(
                    plot = True, 
                    no_of_features = 20
                    )
# Out:
# Result saved as: feature_relevance_score_p_conductivity.pkl
# Figure saved as: feature_relevance_plot_p_conductivity.png
#                                         feature  relevance_score
# 0                        max_packing_efficiency     5.670610e+34
# 1     PymatgenData_minimum_thermal_conductivity     1.133036e+34
# 2                                       total_e     8.013354e+33
# 3            MagpieData_maximum_MendeleevNumber     4.597238e+33
# 4                                       jml_vpa     2.829331e+33
# ...                                         ...              ...
# 2492                        jml_mean_charge_193     0.000000e+00
# 2493                        jml_mean_charge_192     0.000000e+00
# 2494                        jml_mean_charge_191     0.000000e+00
# 2495                        jml_mean_charge_189     0.000000e+00
# 2496                crystal_system_ohe_trigonal     0.000000e+00
#
# [2497 rows x 2 columns]

# %%
# Perform recursive feature selection 
FS.recursive_selection(
                    stratify = False, 
                    oversample_technique = None, 
                    chosen_metric = 'rmse',
                    average = 'weighted',
                    no_to_terminate = 200,
                    max_no_imp = 10
                    )
# Out:
#    No. of rows in training set:  30441
# No. of features considering:  1
#
# n=1: mae_train=330598491118707.3750, mae_validation=323405812628862.5000
# n=1: mse_train=600866354923172315510610067456.0000, mse_validation=599735330678388068633024659456.0000
# n=1: rmse_train=775155697213903.1250, rmse_validation=774425807084441.1250
# n=1: r2_train=0.4757, r2_validation=0.4277
# n=1: max_error_train=9033898617587986.0000, max_error_validation=8864207842577359.0000
# --- 0.9038209915161133 seconds ---
#
# No. of features considering:  2
#
# n=2: mae_train=268638902376129.6562, mae_validation=310166726219466.1250
# n=2: mse_train=413209042815185042673821024256.0000, mse_validation=647705639664054158405513773056.0000
# n=2: rmse_train=642813381017527.5000, rmse_validation=804801615097816.6250
# n=2: r2_train=0.6395, r2_validation=0.3820
# n=2: max_error_train=8783319469486816.0000, max_error_validation=9645422820262124.0000
# --- 0.43439459800720215 seconds ---
#
# No. of features considering:  3
#
# n=3: mae_train=213821801413625.1562, mae_validation=294240135829579.9375
# n=3: mse_train=254412634224072721591221354496.0000, mse_validation=602533657599611802187980603392.0000
# n=3: rmse_train=504393332850537.1250, rmse_validation=776230415276038.8750
# n=3: r2_train=0.7780, r2_validation=0.4251
# n=3: max_error_train=7544328241458758.0000, max_error_validation=8080561039961278.0000
# --- 0.48143792152404785 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  4
#
# n=4: mae_train=193962148579476.3438, mae_validation=277707366329445.8750
# n=4: mse_train=210544625885591231511494918144.0000, mse_validation=509822422510744454924750290944.0000
# n=4: rmse_train=458851420271956.0625, rmse_validation=714018502919038.1250
# n=4: r2_train=0.8163, r2_validation=0.5135
# n=4: max_error_train=7511738605091902.0000, max_error_validation=8166210060507528.0000
# --- 0.49845314025878906 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  5
#
# n=5: mae_train=158217681633076.6875, mae_validation=505776539151646.4375
# n=5: mse_train=128302265126984215705608519680.0000, mse_validation=1030984827503254031560068825088.0000
# n=5: rmse_train=358193055665494.7500, rmse_validation=1015374230273377.6250
# n=5: r2_train=0.8881, r2_validation=0.0162
# n=5: max_error_train=6012706346412510.0000, max_error_validation=7477898236536960.0000
# --- 0.48143744468688965 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  6
#
# n=6: mae_train=135326670147829.7500, mae_validation=456378933487061.1875
# n=6: mse_train=89010686656430169577247211520.0000, mse_validation=722576008289110917154661728256.0000
# n=6: rmse_train=298346588142767.5625, rmse_validation=850044709582449.5000
# n=6: r2_train=0.9223, r2_validation=0.3105
# n=6: max_error_train=5062630462518476.0000, max_error_validation=6525969942633400.0000
# --- 0.42238402366638184 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  7
#
# n=7: mae_train=134963317095462.0156, mae_validation=448476051060135.3750
# n=7: mse_train=87172782317674005853332570112.0000, mse_validation=700717190084763069984073056256.0000
# n=7: rmse_train=295250372256622.2500, rmse_validation=837088519862005.3750
# n=7: r2_train=0.9239, r2_validation=0.3314
# n=7: max_error_train=5124171814528726.0000, max_error_validation=6828548364689276.0000
# --- 0.5054595470428467 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  8
#
# n=8: mae_train=134453496330562.7656, mae_validation=442857292243003.8125
# n=8: mse_train=87170568908220150010217496576.0000, mse_validation=700994462089391821128428683264.0000
# n=8: rmse_train=295246623872687.4375, rmse_validation=837254120377673.5000
# n=8: r2_train=0.9239, r2_validation=0.3311
# n=8: max_error_train=5250957827886930.0000, max_error_validation=6373479949701837.0000
# --- 0.5484979152679443 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  9
#
# n=9: mae_train=123935131037661.2969, mae_validation=424631267989953.3750
# n=9: mse_train=76369450982192722881839890432.0000, mse_validation=661676381378302685098622844928.0000
# n=9: rmse_train=276350232462707.9375, rmse_validation=813434927562311.3750
# n=9: r2_train=0.9334, r2_validation=0.3686
# n=9: max_error_train=4660695989598117.0000, max_error_validation=7248019997957503.0000
# --- 0.49144649505615234 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  10
#
# n=10: mae_train=121803018860007.8125, mae_validation=424070059395043.1875
# n=10: mse_train=73023012569482424689159569408.0000, mse_validation=681526036000844809650678267904.0000
# n=10: rmse_train=270227705036849.2812, rmse_validation=825545901813366.6250
# n=10: r2_train=0.9363, r2_validation=0.3497
# n=10: max_error_train=4445698112247596.0000, max_error_validation=7460558631268918.0000
# --- 0.46942663192749023 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  11
#
# n=11: mae_train=118801286891474.0781, mae_validation=427847502031727.3750
# n=11: mse_train=69054336896387438174072209408.0000, mse_validation=687882257547533531787741364224.0000
# n=11: rmse_train=262781918891668.5000, rmse_validation=829386675530499.1250
# n=11: r2_train=0.9397, r2_validation=0.3436
# n=11: max_error_train=4843461740224388.0000, max_error_validation=8248916934202697.0000
# --- 0.46442174911499023 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  12
#
# n=12: mae_train=113425718232958.5469, mae_validation=388636600982669.0000
# n=12: mse_train=60781465941620443406904852480.0000, mse_validation=618973756672739370846853791744.0000
# n=12: rmse_train=246538974488052.1875, rmse_validation=786748852349172.1250
# n=12: r2_train=0.9470, r2_validation=0.4094
# n=12: max_error_train=4299649747812389.0000, max_error_validation=6207058002017671.0000
# --- 0.4674251079559326 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  13
#
# n=13: mae_train=111409238902580.7188, mae_validation=378860122141564.4375
# n=13: mse_train=59779882323425188260647796736.0000, mse_validation=552817870577679657538158592000.0000
# n=13: rmse_train=244499248104007.8438, rmse_validation=743517229509632.6250
# n=13: r2_train=0.9478, r2_validation=0.4725
# n=13: max_error_train=4863820414487639.0000, max_error_validation=6799368959616094.0000
# --- 0.6445856094360352 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  14
#
# n=14: mae_train=110773034233581.5000, mae_validation=388876520549871.0000
# n=14: mse_train=58567927770327689671877853184.0000, mse_validation=575763745800677097626014842880.0000
# n=14: rmse_train=242008115091886.3125, rmse_validation=758790976356912.8750
# n=14: r2_train=0.9489, r2_validation=0.4506
# n=14: max_error_train=4468311933799355.0000, max_error_validation=7176616267363908.0000
# --- 0.6906278133392334 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  15
#
# n=15: mae_train=106239227434723.6250, mae_validation=372092676248259.4375
# n=15: mse_train=53128088216131995244368494592.0000, mse_validation=438531280548018750969494896640.0000
# n=15: rmse_train=230495310616359.3750, rmse_validation=662216943718611.5000
# n=15: r2_train=0.9536, r2_validation=0.5815
# n=15: max_error_train=4263300117090470.0000, max_error_validation=5759149207253692.0000
# --- 0.6225659847259521 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  16
#
# n=16: mae_train=105889812425629.7969, mae_validation=343604406997239.5625
# n=16: mse_train=52942085602698713319451131904.0000, mse_validation=447760822214339389184062521344.0000
# n=16: rmse_train=230091472251143.4375, rmse_validation=669149327291255.2500
# n=16: r2_train=0.9538, r2_validation=0.5727
# n=16: max_error_train=4147319272579170.0000, max_error_validation=5655777943198866.0000
# --- 0.6876254081726074 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  17
#
# n=17: mae_train=102017078862460.7812, mae_validation=327119633055435.6875
# n=17: mse_train=49133416006559452558375518208.0000, mse_validation=421281793014033745381848776704.0000
# n=17: rmse_train=221660587400104.6875, rmse_validation=649062241248120.7500
# n=17: r2_train=0.9571, r2_validation=0.5980
# n=17: max_error_train=3690233707337826.5000, max_error_validation=5839827135762270.0000
# --- 0.7236580848693848 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  18
#
# n=18: mae_train=99660884988753.4688, mae_validation=356455209759792.8750
# n=18: mse_train=46218282098080569969665376256.0000, mse_validation=453579169646172849610057318400.0000
# n=18: rmse_train=214984376404613.5625, rmse_validation=673482865146673.8750
# n=18: r2_train=0.9597, r2_validation=0.5672
# n=18: max_error_train=3842858917417510.5000, max_error_validation=5966726594568716.0000
# --- 0.6045494079589844 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  19
#
# n=19: mae_train=95326802739058.0156, mae_validation=370790329737823.0000
# n=19: mse_train=41564020654802714188236980224.0000, mse_validation=481152458008142715350769729536.0000
# n=19: rmse_train=203872559837764.1250, rmse_validation=693651539325144.6250
# n=19: r2_train=0.9637, r2_validation=0.5409
# n=19: max_error_train=3577360366869065.5000, max_error_validation=5731206144678325.0000
# --- 0.6335756778717041 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  20
#
# n=20: mae_train=91842250873232.4219, mae_validation=416523449862739.1875
# n=20: mse_train=38852984897602712745608740864.0000, mse_validation=518959265494039589101475201024.0000
# n=20: rmse_train=197111605182451.6875, rmse_validation=720388274123086.7500
# n=20: r2_train=0.9661, r2_validation=0.5048
# n=20: max_error_train=3553283273934420.0000, max_error_validation=5794736128032050.0000
# --- 0.6766149997711182 seconds ---
#
# No. of no improvements:  3
# No. of features considering:  21
#
# n=21: mae_train=91534314886946.6562, mae_validation=397936660359823.2500
# n=21: mse_train=38030213131982034908374630400.0000, mse_validation=485772094216547356430288551936.0000
# n=21: rmse_train=195013366546967.8438, rmse_validation=696973524760121.2500
# n=21: r2_train=0.9668, r2_validation=0.5365
# n=21: max_error_train=3594763974306622.0000, max_error_validation=6155921716717195.0000
# --- 0.7166516780853271 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  22
#
# n=22: mae_train=89897670750844.7656, mae_validation=354246274458336.1875
# n=22: mse_train=37288659062865166111973834752.0000, mse_validation=419977875115453033325271187456.0000
# n=22: rmse_train=193102716352891.2188, rmse_validation=648056999896963.6250
# n=22: r2_train=0.9675, r2_validation=0.5993
# n=22: max_error_train=3439643277431955.0000, max_error_validation=5640409681644517.0000
# --- 0.7396721839904785 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  23
#
# n=23: mae_train=89565454697772.6250, mae_validation=315331447024813.0000
# n=23: mse_train=37433822058658967247545958400.0000, mse_validation=383435098324799015070933712896.0000
# n=23: rmse_train=193478221148166.8750, rmse_validation=619221364557780.0000
# n=23: r2_train=0.9673, r2_validation=0.6341
# n=23: max_error_train=3397810156435414.0000, max_error_validation=5687891400001146.0000
# --- 0.7426745891571045 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  24
#
# n=24: mae_train=88364118198925.5625, mae_validation=339858473224045.5000
# n=24: mse_train=35791695837758605703113605120.0000, mse_validation=411063449676374631423347261440.0000
# n=24: rmse_train=189186933580938.9375, rmse_validation=641142300645008.6250
# n=24: r2_train=0.9688, r2_validation=0.6078
# n=24: max_error_train=3301035588101837.5000, max_error_validation=5803474124257005.0000
# --- 0.8067333698272705 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  25
#
# n=25: mae_train=87590538874071.2031, mae_validation=331644823524293.7500
# n=25: mse_train=34783260419545371067511996416.0000, mse_validation=393244785236333555150644838400.0000
# n=25: rmse_train=186502708879912.4375, rmse_validation=627092325926839.5000
# n=25: r2_train=0.9697, r2_validation=0.6248
# n=25: max_error_train=3237447397873710.0000, max_error_validation=5589476769708171.0000
# --- 0.6766152381896973 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  26
#
# n=26: mae_train=86098686175178.3750, mae_validation=328513469383593.2500
# n=26: mse_train=33494343690392549028456824832.0000, mse_validation=374000499700333577630461722624.0000
# n=26: rmse_train=183014599664596.5625, rmse_validation=611555802605398.8750
# n=26: r2_train=0.9708, r2_validation=0.6431
# n=26: max_error_train=3259077988380266.0000, max_error_validation=5635041204100013.0000
# --- 0.6826205253601074 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  27
#
# n=27: mae_train=86088127869030.9844, mae_validation=333651261393485.6875
# n=27: mse_train=33094966825120567258811203584.0000, mse_validation=392590395019936932820976402432.0000
# n=27: rmse_train=181920221045161.9062, rmse_validation=626570343233652.3750
# n=27: r2_train=0.9711, r2_validation=0.6254
# n=27: max_error_train=3190180104815256.0000, max_error_validation=5968538165520275.0000
# --- 0.6886260509490967 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  28
#
# n=28: mae_train=85227775806133.3438, mae_validation=242546268547518.0312
# n=28: mse_train=32932812822500118134849011712.0000, mse_validation=265139003326022176963368583168.0000
# n=28: rmse_train=181474000403639.4062, rmse_validation=514916501314555.0625
# n=28: r2_train=0.9713, r2_validation=0.7470
# n=28: max_error_train=3336088313399032.5000, max_error_validation=5923193281903981.0000
# --- 0.7897176742553711 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  29
#
# n=29: mae_train=84811944723376.7031, mae_validation=250190406491098.7188
# n=29: mse_train=32171792503852392548935925760.0000, mse_validation=274312280084661353860604887040.0000
# n=29: rmse_train=179364970113599.3750, rmse_validation=523748298407413.8125
# n=29: r2_train=0.9719, r2_validation=0.7382
# n=29: max_error_train=3033435495361861.5000, max_error_validation=6323243248044040.0000
# --- 0.7807092666625977 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  30
#
# n=30: mae_train=84063610389661.7812, mae_validation=248283612936133.0000
# n=30: mse_train=31843625106057596434470928384.0000, mse_validation=265769242772692763046332858368.0000
# n=30: rmse_train=178447821802502.2500, rmse_validation=515528120254067.9375
# n=30: r2_train=0.9722, r2_validation=0.7464
# n=30: max_error_train=3345684235822503.5000, max_error_validation=6361160403005252.0000
# --- 0.7767057418823242 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  31
#
# n=31: mae_train=84057094499398.9844, mae_validation=246060714018048.1562
# n=31: mse_train=31294870479757672501603205120.0000, mse_validation=265162317178060793805650526208.0000
# n=31: rmse_train=176903562654226.0312, rmse_validation=514939139295180.0000
# n=31: r2_train=0.9727, r2_validation=0.7470
# n=31: max_error_train=3063156764101330.0000, max_error_validation=5915338793601862.0000
# --- 0.8277523517608643 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  32
#
# n=32: mae_train=82544293560786.1094, mae_validation=244924558852344.0000
# n=32: mse_train=29796000435640539137527775232.0000, mse_validation=265158840390286681537840676864.0000
# n=32: rmse_train=172615180200469.4375, rmse_validation=514935763363049.6875
# n=32: r2_train=0.9740, r2_validation=0.7470
# n=32: max_error_train=2933959364752067.0000, max_error_validation=6359926624331873.0000
# --- 0.6876249313354492 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  33
#
# n=33: mae_train=81356198933884.6719, mae_validation=246975597042000.9375
# n=33: mse_train=29388726250179552838187745280.0000, mse_validation=274899817674652457729454505984.0000
# n=33: rmse_train=171431403920575.6250, rmse_validation=524308895284690.4375
# n=33: r2_train=0.9744, r2_validation=0.7377
# n=33: max_error_train=3225823594422805.0000, max_error_validation=6262539235266136.0000
# --- 0.7156505584716797 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  34
#
# n=34: mae_train=81848599947363.2188, mae_validation=233981942864698.6875
# n=34: mse_train=29635699291507976765259644928.0000, mse_validation=262684057967070409514282909696.0000
# n=34: rmse_train=172150223036474.6875, rmse_validation=512527129005939.0000
# n=34: r2_train=0.9741, r2_validation=0.7493
# n=34: max_error_train=3527064172612546.5000, max_error_validation=6332321130560685.0000
# --- 0.8557772636413574 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  35
#
# n=35: mae_train=79671946349642.2812, mae_validation=245060981751845.0000
# n=35: mse_train=27792031412539141481184624640.0000, mse_validation=252328957356888762802369462272.0000
# n=35: rmse_train=166709422086872.8750, rmse_validation=502323558433096.7500
# n=35: r2_train=0.9758, r2_validation=0.7592
# n=35: max_error_train=2972163726514365.0000, max_error_validation=5815960133180994.0000
# --- 0.888808012008667 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  36
#
# n=36: mae_train=79993505072827.0625, mae_validation=232790871414966.5625
# n=36: mse_train=27739062277460358147229089792.0000, mse_validation=239396585929367901479106510848.0000
# n=36: rmse_train=166550479667458.0625, rmse_validation=489281704061543.5625
# n=36: r2_train=0.9758, r2_validation=0.7716
# n=36: max_error_train=3374280662749369.0000, max_error_validation=6008238644930362.0000
# --- 0.7666966915130615 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  37
#
# n=37: mae_train=79612641628887.8438, mae_validation=237668266638396.9375
# n=37: mse_train=27673698300957486431411896320.0000, mse_validation=251194554584323309379331817472.0000
# n=37: rmse_train=166354135208468.6875, rmse_validation=501193131022686.0000
# n=37: r2_train=0.9759, r2_validation=0.7603
# n=37: max_error_train=3335776663715249.0000, max_error_validation=6522806904526456.0000
# --- 0.9128296375274658 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  38
#
# n=38: mae_train=78752358273756.1562, mae_validation=236564239923491.6250
# n=38: mse_train=26763544010755098492218114048.0000, mse_validation=244638224257523884570678657024.0000
# n=38: rmse_train=163595672347269.3125, rmse_validation=494609163135423.4375
# n=38: r2_train=0.9766, r2_validation=0.7666
# n=38: max_error_train=3185678252273563.0000, max_error_validation=6658638077324620.0000
# --- 0.7616920471191406 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  39
#
# n=39: mae_train=78266844797957.8594, mae_validation=240620378935920.1875
# n=39: mse_train=26325059818992033798664749056.0000, mse_validation=248283646001626073237387476992.0000
# n=39: rmse_train=162249991738033.7812, rmse_validation=498280689974662.8750
# n=39: r2_train=0.9770, r2_validation=0.7631
# n=39: max_error_train=3268420368369861.0000, max_error_validation=6214337410058561.0000
# --- 0.7426750659942627 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  40
#
# n=40: mae_train=78222283276739.5000, mae_validation=233275656581663.6875
# n=40: mse_train=26366995242650625215664488448.0000, mse_validation=243700852995501827685519196160.0000
# n=40: rmse_train=162379171209396.8750, rmse_validation=493660665837882.8125
# n=40: r2_train=0.9770, r2_validation=0.7675
# n=40: max_error_train=3183457360849923.5000, max_error_validation=6247596886479428.0000
# --- 0.8627839088439941 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  41
#
# n=41: mae_train=78738688284323.0625, mae_validation=254446641905001.4062
# n=41: mse_train=26991023856266997086388486144.0000, mse_validation=262118513596426637301545697280.0000
# n=41: rmse_train=164289451445511.2500, rmse_validation=511975110329034.1250
# n=41: r2_train=0.9764, r2_validation=0.7499
# n=41: max_error_train=3090215018556248.5000, max_error_validation=5785165535367135.0000
# --- 0.9118289947509766 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  42
#
# n=42: mae_train=78312396801356.3281, mae_validation=270681327192103.5000
# n=42: mse_train=26984665406167944365938311168.0000, mse_validation=260694667284825183584761413632.0000
# n=42: rmse_train=164270098941249.6250, rmse_validation=510582674289703.2500
# n=42: r2_train=0.9765, r2_validation=0.7512
# n=42: max_error_train=3332934323158577.5000, max_error_validation=5628142771413320.0000
# --- 0.8437666893005371 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  43
#
# n=43: mae_train=76927428858932.8906, mae_validation=235243541069337.5625
# n=43: mse_train=25522291646695546926519025664.0000, mse_validation=237741155016048477201143693312.0000
# n=43: rmse_train=159756976832611.4375, rmse_validation=487587074291401.3125
# n=43: r2_train=0.9777, r2_validation=0.7731
# n=43: max_error_train=3510506062257968.0000, max_error_validation=5723757987187438.0000
# --- 0.9498634338378906 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  44
#
# n=44: mae_train=77090221805664.1406, mae_validation=219917234870472.8125
# n=44: mse_train=25871530420822046746228031488.0000, mse_validation=229072934231978383555254288384.0000
# n=44: rmse_train=160846294395680.9062, rmse_validation=478615643530357.6250
# n=44: r2_train=0.9774, r2_validation=0.7814
# n=44: max_error_train=3084693424676971.5000, max_error_validation=6236474750561993.0000
# --- 0.8017284870147705 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  45
#
# n=45: mae_train=77140673826674.1250, mae_validation=224634366210653.5625
# n=45: mse_train=25873534774583934995402850304.0000, mse_validation=227471841865347389299114377216.0000
# n=45: rmse_train=160852524924490.8125, rmse_validation=476940082049461.8125
# n=45: r2_train=0.9774, r2_validation=0.7829
# n=45: max_error_train=3180063099174931.5000, max_error_validation=5821095469289346.0000
# --- 0.8307552337646484 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  46
#
# n=46: mae_train=75841944303861.1719, mae_validation=230075366727666.8750
# n=46: mse_train=24679024318178092628918140928.0000, mse_validation=232943239509892428005908676608.0000
# n=46: rmse_train=157095589747701.3750, rmse_validation=482641937164490.9375
# n=46: r2_train=0.9785, r2_validation=0.7777
# n=46: max_error_train=3331970685665217.0000, max_error_validation=6176859173740300.0000
# --- 0.934849739074707 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  47
#
# n=47: mae_train=75639347536924.7656, mae_validation=240633410660848.8438
# n=47: mse_train=24705552259963033061133647872.0000, mse_validation=233891130471172973509121933312.0000
# n=47: rmse_train=157179999554533.1250, rmse_validation=483622921780154.0000
# n=47: r2_train=0.9784, r2_validation=0.7768
# n=47: max_error_train=3084949449367039.0000, max_error_validation=6154833125217698.0000
# --- 0.9158322811126709 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  48
#
# n=48: mae_train=76367906210269.1719, mae_validation=224575800096666.6875
# n=48: mse_train=25104084006381157117348282368.0000, mse_validation=227068346056177793383884914688.0000
# n=48: rmse_train=158442683663150.4375, rmse_validation=476516889581238.0000
# n=48: r2_train=0.9781, r2_validation=0.7833
# n=48: max_error_train=3323109274816493.5000, max_error_validation=6075653790839922.0000
# --- 0.9298458099365234 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  49
#
# n=49: mae_train=75835105934657.8594, mae_validation=229670422090757.1250
# n=49: mse_train=24574972399552482809246384128.0000, mse_validation=223946532288962674682706788352.0000
# n=49: rmse_train=156764066034128.1250, rmse_validation=473229893697516.3750
# n=49: r2_train=0.9786, r2_validation=0.7863
# n=49: max_error_train=2963402671605689.5000, max_error_validation=6236608742412700.0000
# --- 0.9558689594268799 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  50
#
# n=50: mae_train=74622834812476.7969, mae_validation=218742797762721.6562
# n=50: mse_train=23656540123701813769029025792.0000, mse_validation=222132492090421593676634390528.0000
# n=50: rmse_train=153806827298731.5000, rmse_validation=471309338004692.6250
# n=50: r2_train=0.9794, r2_validation=0.7880
# n=50: max_error_train=3135531399515315.0000, max_error_validation=6188125306509495.0000
# --- 0.8147401809692383 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  51
#
# n=51: mae_train=75563839930165.6094, mae_validation=229779355607885.2812
# n=51: mse_train=24480622915158138196919844864.0000, mse_validation=230972574747137767869188669440.0000
# n=51: rmse_train=156462848354355.7812, rmse_validation=480596061934695.6250
# n=51: r2_train=0.9786, r2_validation=0.7796
# n=51: max_error_train=3313401574968532.5000, max_error_validation=6163904709494423.0000
# --- 0.9418559074401855 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  52
#
# n=52: mae_train=75226163769493.8594, mae_validation=222934048856838.2812
# n=52: mse_train=24394411279055505651708985344.0000, mse_validation=228312853982069329371810758656.0000
# n=52: rmse_train=156187103433847.9062, rmse_validation=477820943431814.5625
# n=52: r2_train=0.9787, r2_validation=0.7821
# n=52: max_error_train=3043537481110052.5000, max_error_validation=6183122336413734.0000
# --- 1.028935194015503 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  53
#
# n=53: mae_train=74548427847817.2500, mae_validation=225207226637109.5000
# n=53: mse_train=23432089811355041761197031424.0000, mse_validation=230934924808947410782526636032.0000
# n=53: rmse_train=153075438302018.4062, rmse_validation=480556890293904.1250
# n=53: r2_train=0.9796, r2_validation=0.7796
# n=53: max_error_train=3037517419254027.0000, max_error_validation=6349027008432738.0000
# --- 1.1500451564788818 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  54
#
# n=54: mae_train=73560489658500.2188, mae_validation=218140739759907.8125
# n=54: mse_train=22998344417111050518060335104.0000, mse_validation=224001822464641620900050894848.0000
# n=54: rmse_train=151652050487657.5938, rmse_validation=473288307973735.6250
# n=54: r2_train=0.9799, r2_validation=0.7863
# n=54: max_error_train=2719825430927459.0000, max_error_validation=6225483828705718.0000
# --- 0.9959049224853516 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  55
#
# n=55: mae_train=72929385146284.3594, mae_validation=226897393320981.1875
# n=55: mse_train=22559472738567424031519145984.0000, mse_validation=230942533627640654525982834688.0000
# n=55: rmse_train=150198111634492.3438, rmse_validation=480564806896677.1875
# n=55: r2_train=0.9803, r2_validation=0.7796
# n=55: max_error_train=2729942960473770.5000, max_error_validation=6396280930695213.0000
# --- 0.8497719764709473 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  56
#
# n=56: mae_train=73705861763483.4688, mae_validation=225770400996293.5938
# n=56: mse_train=23145047026429498224642359296.0000, mse_validation=224527336941797110144812711936.0000
# n=56: rmse_train=152134963195280.9688, rmse_validation=473843156478804.8125
# n=56: r2_train=0.9798, r2_validation=0.7858
# n=56: max_error_train=2800564232942559.0000, max_error_validation=6013534789352672.0000
# --- 0.9648768901824951 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  57
#
# n=57: mae_train=73320790100366.6406, mae_validation=250068784873394.4062
# n=57: mse_train=22600190718468727407604924416.0000, mse_validation=234216799738429338785203355648.0000
# n=57: rmse_train=150333598102582.2812, rmse_validation=483959502167722.0000
# n=57: r2_train=0.9803, r2_validation=0.7765
# n=57: max_error_train=2883223887702000.0000, max_error_validation=6005183063774904.0000
# --- 1.0399456024169922 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  58
#
# n=58: mae_train=72724170808739.9688, mae_validation=216751425763056.8750
# n=58: mse_train=22247945537850612125995630592.0000, mse_validation=216964457743315678742219587584.0000
# n=58: rmse_train=149157452170016.0000, rmse_validation=465794437218088.3750
# n=58: r2_train=0.9806, r2_validation=0.7930
# n=58: max_error_train=2661409321965951.0000, max_error_validation=5924190218472635.0000
# --- 1.092993974685669 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  59
#
# n=59: mae_train=72735345614483.4844, mae_validation=259626625357672.3750
# n=59: mse_train=22580478514869832683305828352.0000, mse_validation=236811758222237207954578210816.0000
# n=59: rmse_train=150268022263121.0000, rmse_validation=486633083772812.5625
# n=59: r2_train=0.9803, r2_validation=0.7740
# n=59: max_error_train=2682209021706504.5000, max_error_validation=5879018467534886.0000
# --- 0.9949040412902832 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  60
#
# n=60: mae_train=72459600423220.2656, mae_validation=230983888189796.8750
# n=60: mse_train=22176778003345488491462000640.0000, mse_validation=224821504158847860010888724480.0000
# n=60: rmse_train=148918695949653.9688, rmse_validation=474153460557705.8125
# n=60: r2_train=0.9806, r2_validation=0.7855
# n=60: max_error_train=2740746073606569.0000, max_error_validation=6274112941984580.0000
# --- 0.9438581466674805 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  61
#
# n=61: mae_train=72830061313100.0000, mae_validation=215949863532345.8125
# n=61: mse_train=22277706572845960444866723840.0000, mse_validation=220343509536510646957501317120.0000
# n=61: rmse_train=149257182650772.1562, rmse_validation=469407615550185.3750
# n=61: r2_train=0.9806, r2_validation=0.7897
# n=61: max_error_train=2727816447068233.0000, max_error_validation=6269344384347185.0000
# --- 1.078981637954712 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  62
#
# n=62: mae_train=71228528501443.5938, mae_validation=227242868899104.0938
# n=62: mse_train=21285403827892594094395883520.0000, mse_validation=228939143149916154921452830720.0000
# n=62: rmse_train=145895180961855.5938, rmse_validation=478475854301882.3750
# n=62: r2_train=0.9814, r2_validation=0.7815
# n=62: max_error_train=2684465150670685.5000, max_error_validation=6385206725415916.0000
# --- 1.0699725151062012 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  63
#
# n=63: mae_train=71953510123734.4844, mae_validation=223142426312272.1875
# n=63: mse_train=21666638846537762307208904704.0000, mse_validation=218868509460610107114323443712.0000
# n=63: rmse_train=147195919938487.9688, rmse_validation=467833848134794.6250
# n=63: r2_train=0.9811, r2_validation=0.7912
# n=63: max_error_train=2764647504336385.0000, max_error_validation=6233900520822868.0000
# --- 1.2541399002075195 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  64
#
# n=64: mae_train=72059078474834.5781, mae_validation=223074147089631.9375
# n=64: mse_train=22003644332792124709856608256.0000, mse_validation=223006177280808997643819679744.0000
# n=64: rmse_train=148336254276532.5625, rmse_validation=472235298639151.9375
# n=64: r2_train=0.9808, r2_validation=0.7872
# n=64: max_error_train=2683643012596774.0000, max_error_validation=6243116095650184.0000
# --- 0.9919013977050781 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  65
#
# n=65: mae_train=71749024685128.3125, mae_validation=230185897602547.0312
# n=65: mse_train=21503087972696637078627155968.0000, mse_validation=218474002233960910590350196736.0000
# n=65: rmse_train=146639312507583.1562, rmse_validation=467412026197402.1250
# n=65: r2_train=0.9812, r2_validation=0.7915
# n=65: max_error_train=2653403642139289.0000, max_error_validation=6252156068850404.0000
# --- 0.8908095359802246 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  66
#
# n=66: mae_train=71752471000276.5625, mae_validation=227145447928909.5938
# n=66: mse_train=21901666355482701835393826816.0000, mse_validation=225683113334852756753898012672.0000
# n=66: rmse_train=147992115855820.8438, rmse_validation=475061167992978.3125
# n=66: r2_train=0.9809, r2_validation=0.7847
# n=66: max_error_train=2683524963450242.0000, max_error_validation=6128153805235031.0000
# --- 1.0269336700439453 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  67
#
# n=67: mae_train=71526469321118.2656, mae_validation=239355988006866.0000
# n=67: mse_train=21457933963398633272930992128.0000, mse_validation=232476897337121977784082628608.0000
# n=67: rmse_train=146485268759007.4062, rmse_validation=482158581109080.7500
# n=67: r2_train=0.9813, r2_validation=0.7782
# n=67: max_error_train=2866871832044055.5000, max_error_validation=5891146663035092.0000
# --- 1.0049128532409668 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  68
#
# n=68: mae_train=71269258826878.8125, mae_validation=235104431804130.2188
# n=68: mse_train=21372341813076465084650225664.0000, mse_validation=228374923660895502755438788608.0000
# n=68: rmse_train=146192824082020.0625, rmse_validation=477885889790539.3125
# n=68: r2_train=0.9814, r2_validation=0.7821
# n=68: max_error_train=2709768468986771.5000, max_error_validation=5773926486132172.0000
# --- 1.0819833278656006 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  69
#
# n=69: mae_train=71159340431414.4062, mae_validation=218808893379906.8438
# n=69: mse_train=21127711449310202433281982464.0000, mse_validation=215332676282681389647038251008.0000
# n=69: rmse_train=145353745907390.3750, rmse_validation=464039520173316.0625
# n=69: r2_train=0.9816, r2_validation=0.7945
# n=69: max_error_train=2760355318435275.0000, max_error_validation=6072595508400739.0000
# --- 1.0089170932769775 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  70
#
# n=70: mae_train=70891616328886.1875, mae_validation=219680360349586.8125
# n=70: mse_train=21065733837743289352497135616.0000, mse_validation=220528261307953317670595592192.0000
# n=70: rmse_train=145140393542746.3750, rmse_validation=469604366789698.1250
# n=70: r2_train=0.9816, r2_validation=0.7896
# n=70: max_error_train=2652883190951184.5000, max_error_validation=5945124291562490.0000
# --- 0.8938126564025879 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  71
#
# n=71: mae_train=71205344655221.2812, mae_validation=217651622040951.0000
# n=71: mse_train=21254016464171828644585406464.0000, mse_validation=216730550882066851321180323840.0000
# n=71: rmse_train=145787573078681.2500, rmse_validation=465543285723322.2500
# n=71: r2_train=0.9815, r2_validation=0.7932
# n=71: max_error_train=2759942738233413.0000, max_error_validation=6256688291411641.0000
# --- 1.1350321769714355 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  72
#
# n=72: mae_train=70684623886345.8281, mae_validation=216783646189453.6250
# n=72: mse_train=20711272915293416668960653312.0000, mse_validation=218871430174931751630893219840.0000
# n=72: rmse_train=143914116455938.4688, rmse_validation=467836969653886.7500
# n=72: r2_train=0.9819, r2_validation=0.7912
# n=72: max_error_train=2656374323401959.5000, max_error_validation=6217962219991098.0000
# --- 1.115013599395752 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  73
#
# n=73: mae_train=71212135014740.5938, mae_validation=217557510491339.1250
# n=73: mse_train=21174200512580079901479010304.0000, mse_validation=212220698704893284805326667776.0000
# n=73: rmse_train=145513575011337.2812, rmse_validation=460674178465532.5000
# n=73: r2_train=0.9815, r2_validation=0.7975
# n=73: max_error_train=2723127340344738.0000, max_error_validation=6134470286989414.0000
# --- 1.3131933212280273 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  74
#
# n=74: mae_train=70721562326668.3594, mae_validation=227761143584250.3750
# n=74: mse_train=20862834194463048694727966720.0000, mse_validation=227760775754231154041786728448.0000
# n=74: rmse_train=144439725125960.5938, rmse_validation=477242889684310.6875
# n=74: r2_train=0.9818, r2_validation=0.7827
# n=74: max_error_train=2796998686397009.5000, max_error_validation=6265533249009064.0000
# --- 0.9718832969665527 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  75
#
# n=75: mae_train=71111460354481.5312, mae_validation=229071289785738.3125
# n=75: mse_train=21209698192228505737683271680.0000, mse_validation=223355720147505238513912119296.0000
# n=75: rmse_train=145635497706529.3125, rmse_validation=472605247693574.8750
# n=75: r2_train=0.9815, r2_validation=0.7869
# n=75: max_error_train=2721672302438769.5000, max_error_validation=6295457212797716.0000
# --- 1.050954818725586 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  76
#
# n=76: mae_train=70240594012460.8906, mae_validation=218052416399801.1562
# n=76: mse_train=20413628238576565710089093120.0000, mse_validation=216034849119367001943561994240.0000
# n=76: rmse_train=142876268983258.9688, rmse_validation=464795491715837.3125
# n=76: r2_train=0.9822, r2_validation=0.7939
# n=76: max_error_train=2669584074714184.5000, max_error_validation=6328772241092659.0000
# --- 1.1740670204162598 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  77
#
# n=77: mae_train=70141706354757.1094, mae_validation=222592542113444.7500
# n=77: mse_train=20471318025365361893247549440.0000, mse_validation=219797719797313369656805818368.0000
# n=77: rmse_train=143078013773484.2812, rmse_validation=468825894973084.1875
# n=77: r2_train=0.9821, r2_validation=0.7903
# n=77: max_error_train=2693095244738840.0000, max_error_validation=6339679264349269.0000
# --- 1.164057970046997 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  78
#
# n=78: mae_train=70975942850314.9844, mae_validation=217408683215872.1250
# n=78: mse_train=21358723355543640042257776640.0000, mse_validation=215863894010277248193838186496.0000
# n=78: rmse_train=146146239621632.5625, rmse_validation=464611551740028.5625
# n=78: r2_train=0.9814, r2_validation=0.7940
# n=78: max_error_train=2782535314529345.0000, max_error_validation=5964191136351551.0000
# --- 1.076979160308838 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  79
#
# n=79: mae_train=69980028377441.9766, mae_validation=214882175825409.4062
# n=79: mse_train=20650256287862961166310440960.0000, mse_validation=218094843183745020147875708928.0000
# n=79: rmse_train=143701970368756.4688, rmse_validation=467006256043476.3750
# n=79: r2_train=0.9820, r2_validation=0.7919
# n=79: max_error_train=2685990362299812.5000, max_error_validation=6300081983940954.0000
# --- 1.0439486503601074 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  80
#
# n=80: mae_train=71300259949783.5781, mae_validation=239304439080876.2500
# n=80: mse_train=21385256720511689056728383488.0000, mse_validation=227061838133193184546064957440.0000
# n=80: rmse_train=146236988209247.8438, rmse_validation=476510060893989.0625
# n=80: r2_train=0.9813, r2_validation=0.7833
# n=80: max_error_train=2668875348803121.5000, max_error_validation=6105656264605184.0000
# --- 1.4753413200378418 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  81
#
# n=81: mae_train=69945471128392.7109, mae_validation=229765865141352.8125
# n=81: mse_train=20663212555725999254215327744.0000, mse_validation=223838693044728573308897853440.0000
# n=81: rmse_train=143747043641690.2500, rmse_validation=473115940383251.6875
# n=81: r2_train=0.9820, r2_validation=0.7864
# n=81: max_error_train=2898398508360194.0000, max_error_validation=6041852175454562.0000
# --- 1.121018886566162 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  82
#
# n=82: mae_train=70264910361110.6875, mae_validation=223436156667039.2188
# n=82: mse_train=20718414578807566166577381376.0000, mse_validation=219483322642550923645409034240.0000
# n=82: rmse_train=143938926558480.2188, rmse_validation=468490472307122.7500
# n=82: r2_train=0.9819, r2_validation=0.7906
# n=82: max_error_train=2769587468755465.0000, max_error_validation=6278442822661104.0000
# --- 1.398270845413208 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  83
#
# n=83: mae_train=70718606762094.7344, mae_validation=218217579027385.6250
# n=83: mse_train=21266768149499842295463149568.0000, mse_validation=215870004116740205283874177024.0000
# n=83: rmse_train=145831300307923.7500, rmse_validation=464618127193440.6875
# n=83: r2_train=0.9814, r2_validation=0.7940
# n=83: max_error_train=2855301561464455.5000, max_error_validation=6375593297887455.0000
# --- 1.274158239364624 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  84
#
# n=84: mae_train=70863371548618.5156, mae_validation=220998466938677.0312
# n=84: mse_train=21435332460259581273105760256.0000, mse_validation=220004088830099080793267634176.0000
# n=84: rmse_train=146408102440608.0625, rmse_validation=469045934669621.7500
# n=84: r2_train=0.9813, r2_validation=0.7901
# n=84: max_error_train=2949404594176522.0000, max_error_validation=5960940018550890.0000
# --- 1.497361183166504 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  85
#
# n=85: mae_train=70187702937026.4375, mae_validation=217997980848281.7812
# n=85: mse_train=20931681848569969878457384960.0000, mse_validation=221737534277869907403650105344.0000
# n=85: rmse_train=144677855418754.2812, rmse_validation=470890150967154.8750
# n=85: r2_train=0.9817, r2_validation=0.7884
# n=85: max_error_train=2687453882091611.0000, max_error_validation=6251174961034815.0000
# --- 1.5173795223236084 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  86
#
# n=86: mae_train=69695464884472.9219, mae_validation=209068269867270.1562
# n=86: mse_train=20663794717189822924107808768.0000, mse_validation=206218392392348697524197916672.0000
# n=86: rmse_train=143749068578512.2812, rmse_validation=454112752950573.6250
# n=86: r2_train=0.9820, r2_validation=0.8032
# n=86: max_error_train=2784878032161978.0000, max_error_validation=5777037551644059.0000
# --- 1.377251386642456 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  87
#
# n=87: mae_train=70161669999418.1797, mae_validation=228816281962696.1250
# n=87: mse_train=20538452583160536781836779520.0000, mse_validation=226686372256297675485398171648.0000
# n=87: rmse_train=143312429967398.6250, rmse_validation=476115923128283.6250
# n=87: r2_train=0.9821, r2_validation=0.7837
# n=87: max_error_train=2674969534547861.0000, max_error_validation=6132426024862578.0000
# --- 1.4473161697387695 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  88
#
# n=88: mae_train=69859648816445.1875, mae_validation=210566113852126.1250
# n=88: mse_train=20827349182185282128622649344.0000, mse_validation=212355594008877556848257925120.0000
# n=88: rmse_train=144316836100938.9688, rmse_validation=460820565956943.3125
# n=88: r2_train=0.9818, r2_validation=0.7974
# n=88: max_error_train=2939491070216032.0000, max_error_validation=6367560778963114.0000
# --- 1.5083708763122559 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  89
#
# n=89: mae_train=70018818667986.6406, mae_validation=216518091933839.9062
# n=89: mse_train=20829828639268051385577373696.0000, mse_validation=215211847606575675750978945024.0000
# n=89: rmse_train=144325426170401.6250, rmse_validation=463909309678708.3125
# n=89: r2_train=0.9818, r2_validation=0.7946
# n=89: max_error_train=2759019803838439.5000, max_error_validation=6122955906448138.0000
# --- 1.3872616291046143 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  90
#
# n=90: mae_train=69681136329481.9141, mae_validation=216288378208759.0000
# n=90: mse_train=20367358503742078955464687616.0000, mse_validation=212470929080721875670902243328.0000
# n=90: rmse_train=142714254732111.7500, rmse_validation=460945689947006.5000
# n=90: r2_train=0.9822, r2_validation=0.7973
# n=90: max_error_train=2805619179817956.5000, max_error_validation=6327017729663405.0000
# --- 1.3412196636199951 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  91
#
# n=91: mae_train=68636612943207.2656, mae_validation=209149636036789.1875
# n=91: mse_train=19739985471522884456066056192.0000, mse_validation=208177765399551009167050276864.0000
# n=91: rmse_train=140499058614365.4062, rmse_validation=456265016629097.9375
# n=91: r2_train=0.9828, r2_validation=0.8014
# n=91: max_error_train=2721572908343090.0000, max_error_validation=6156706855146953.0000
# --- 1.6144673824310303 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  92
#
# n=92: mae_train=69433285221418.0156, mae_validation=207460485737663.6562
# n=92: mse_train=20227816710177816938522083328.0000, mse_validation=208117878916125800023482957824.0000
# n=92: rmse_train=142224529214119.0938, rmse_validation=456199385045755.8125
# n=92: r2_train=0.9824, r2_validation=0.8014
# n=92: max_error_train=2743769077328172.0000, max_error_validation=6319536765464981.0000
# --- 1.5163769721984863 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  93
#
# n=93: mae_train=69102459676834.1484, mae_validation=221354342840427.4375
# n=93: mse_train=20388933726737806888691302400.0000, mse_validation=214902475007036999404387041280.0000
# n=93: rmse_train=142789823610570.4062, rmse_validation=463575748941893.0000
# n=93: r2_train=0.9822, r2_validation=0.7949
# n=93: max_error_train=2887585719943286.0000, max_error_validation=6328408768536261.0000
# --- 1.4032750129699707 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  94
#
# n=94: mae_train=69773876889418.3203, mae_validation=218699250418145.5312
# n=94: mse_train=20302622536048536843710365696.0000, mse_validation=216963392965940126992304177152.0000
# n=94: rmse_train=142487271487836.9062, rmse_validation=465793294247502.1875
# n=94: r2_train=0.9823, r2_validation=0.7930
# n=94: max_error_train=2948053505111750.0000, max_error_validation=6324340659666270.0000
# --- 1.492356777191162 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  95
#
# n=95: mae_train=69894361244741.0938, mae_validation=215014769427579.8438
# n=95: mse_train=20423381913948162084988518400.0000, mse_validation=214796183919172300985709101056.0000
# n=95: rmse_train=142910398200929.2500, rmse_validation=463461092130906.1875
# n=95: r2_train=0.9822, r2_validation=0.7950
# n=95: max_error_train=2753200923988466.0000, max_error_validation=6062860690158174.0000
# --- 1.5393991470336914 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  96
#
# n=96: mae_train=68795190564061.6406, mae_validation=220036628214772.5000
# n=96: mse_train=19597995478022482605432111104.0000, mse_validation=213603207287944774268594683904.0000
# n=96: rmse_train=139992840809887.4219, rmse_validation=462172270141713.2500
# n=96: r2_train=0.9829, r2_validation=0.7962
# n=96: max_error_train=2665454694846046.5000, max_error_validation=6297845425018060.0000
# --- 1.471337080001831 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  97
#
# n=97: mae_train=69131544050768.3125, mae_validation=212995675350425.5000
# n=97: mse_train=20240081080562656071091486720.0000, mse_validation=210371118259260857700866588672.0000
# n=97: rmse_train=142267638908371.0625, rmse_validation=458662313973211.5000
# n=97: r2_train=0.9823, r2_validation=0.7993
# n=97: max_error_train=2780852231936719.5000, max_error_validation=6298347817474270.0000
# --- 1.4643311500549316 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  98
#
# n=98: mae_train=69149911957122.2500, mae_validation=210720320550827.6875
# n=98: mse_train=20530712041102921081152339968.0000, mse_validation=206304350744060981291178262528.0000
# n=98: rmse_train=143285421593066.9062, rmse_validation=454207387372839.8125
# n=98: r2_train=0.9821, r2_validation=0.8031
# n=98: max_error_train=3006466498712155.0000, max_error_validation=6059346148237696.0000
# --- 1.611464262008667 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  99
#
# n=99: mae_train=69256384570754.0781, mae_validation=224816474018607.1875
# n=99: mse_train=20413730846003887809266450432.0000, mse_validation=211533683929110129494856826880.0000
# n=99: rmse_train=142876628060728.9688, rmse_validation=459927911665632.8125
# ...
# --- 2.2290263175964355 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  174
#
# n=174: mae_train=62820959323840.7812, mae_validation=248230638950033.2188
# n=174: mse_train=15677705224771442539791122432.0000, mse_validation=229628845935881810856548237312.0000
# n=174: rmse_train=125210643416490.1250, rmse_validation=479196041235611.4375
# n=174: r2_train=0.9863, r2_validation=0.7809
# n=174: max_error_train=3015493486071753.5000, max_error_validation=6182393046624900.0000
# --- 2.116924524307251 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  175
#
# n=175: mae_train=61855702894506.8359, mae_validation=258086126320741.9688
# n=175: mse_train=15411438083079576203829444608.0000, mse_validation=233513663739337009459793756160.0000
# n=175: rmse_train=124142813255861.0000, rmse_validation=483232515192569.6250
# n=175: r2_train=0.9866, r2_validation=0.7772
# n=175: max_error_train=3238158752655908.0000, max_error_validation=6436427274326046.0000
# --- 2.3661506175994873 seconds ---
#
# No. of no improvements:  3
# No. of features considering:  176
#
# n=176: mae_train=61992635141651.2891, mae_validation=233923285682466.5625
# n=176: mse_train=15231461997026699463714930688.0000, mse_validation=221623410205164584097340719104.0000
# n=176: rmse_train=123415809348019.5156, rmse_validation=470768956288713.4375
# n=176: r2_train=0.9867, r2_validation=0.7885
# n=176: max_error_train=2991372663745035.0000, max_error_validation=6399691222650982.0000
# --- 2.0698812007904053 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  177
#
# n=177: mae_train=63149219086117.6953, mae_validation=244295750962259.6875
# n=177: mse_train=15420177855630394818222358528.0000, mse_validation=225567898648382385207000432640.0000
# n=177: rmse_train=124178008744021.9688, rmse_validation=474939889510643.6250
# n=177: r2_train=0.9865, r2_validation=0.7848
# n=177: max_error_train=3017219717096317.5000, max_error_validation=6064509989816242.0000
# --- 2.2860779762268066 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  178
#
# n=178: mae_train=63083666744700.4219, mae_validation=244756877883764.8750
# n=178: mse_train=15356654655496250084097523712.0000, mse_validation=227138319027753899262019108864.0000
# n=178: rmse_train=123921970027498.5469, rmse_validation=476590305217965.8750
# n=178: r2_train=0.9866, r2_validation=0.7833
# n=178: max_error_train=2791718247791307.0000, max_error_validation=6311346475699241.0000
# --- 2.2130117416381836 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  179
#
# n=179: mae_train=62925400453808.8750, mae_validation=228302104367902.5312
# n=179: mse_train=15435435797690027231330435072.0000, mse_validation=215137669264201142812895346688.0000
# n=179: rmse_train=124239429319721.3125, rmse_validation=463829353603457.4375
# n=179: r2_train=0.9865, r2_validation=0.7947
# n=179: max_error_train=2815020522161550.5000, max_error_validation=6172488369401730.0000
# --- 2.311100721359253 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  180
#
# n=180: mae_train=63527808475261.3359, mae_validation=238760756910118.6562
# n=180: mse_train=16156252309603466695764082688.0000, mse_validation=219139514252494066363188379648.0000
# n=180: rmse_train=127107247274116.7812, rmse_validation=468123396395110.8125
# n=180: r2_train=0.9859, r2_validation=0.7909
# n=180: max_error_train=3126760671895695.0000, max_error_validation=6208977087774436.0000
# --- 2.2100086212158203 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  181
#
# n=181: mae_train=62237755012065.5703, mae_validation=255443664435993.0625
# n=181: mse_train=14961012363357550861162119168.0000, mse_validation=222819413026947418922695000064.0000
# n=181: rmse_train=122315217219107.9062, rmse_validation=472037512309082.6875
# n=181: r2_train=0.9869, r2_validation=0.7874
# n=181: max_error_train=3087759614306072.5000, max_error_validation=6195893105991953.0000
# --- 2.403184652328491 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  182
#
# n=182: mae_train=63099259382796.1094, mae_validation=243654897843743.0938
# n=182: mse_train=15725859214626409733792202752.0000, mse_validation=223578691413365123070153457664.0000
# n=182: rmse_train=125402787906116.3906, rmse_validation=472841084734993.3125
# n=182: r2_train=0.9863, r2_validation=0.7867
# n=182: max_error_train=3217500166766818.0000, max_error_validation=6132226185285278.0000
# --- 2.192993402481079 seconds ---
#
# No. of no improvements:  3
# No. of features considering:  183
#
# n=183: mae_train=62303961778484.5703, mae_validation=242953386592572.9062
# n=183: mse_train=15585306357673323727916367872.0000, mse_validation=224859265274903283149748305920.0000
# n=183: rmse_train=124841124464950.7500, rmse_validation=474193278394900.1250
# n=183: r2_train=0.9864, r2_validation=0.7854
# n=183: max_error_train=3096324602730855.0000, max_error_validation=6148249812208100.0000
# --- 2.079890727996826 seconds ---
#
# No. of no improvements:  4
# No. of features considering:  184
#
# n=184: mae_train=62237207447345.0703, mae_validation=236985122441621.7500
# n=184: mse_train=15401691254180078964522876928.0000, mse_validation=223316038544272375952862871552.0000
# n=184: rmse_train=124103550530112.0625, rmse_validation=472563264065534.8125
# n=184: r2_train=0.9866, r2_validation=0.7869
# n=184: max_error_train=2971162838273554.0000, max_error_validation=6575691485262496.0000
# --- 2.316105604171753 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  185
#
# n=185: mae_train=62547041326681.6250, mae_validation=244461293969520.5000
# n=185: mse_train=15518342385591912277169143808.0000, mse_validation=223251328036278844035537305600.0000
# n=185: rmse_train=124572638992645.2188, rmse_validation=472494791544074.9375
# n=185: r2_train=0.9865, r2_validation=0.7870
# n=185: max_error_train=2975490009009188.0000, max_error_validation=6244992869173150.0000
# --- 2.236032485961914 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  186
#
# n=186: mae_train=62155586229979.4688, mae_validation=243669064126199.1562
# n=186: mse_train=15441643631104737571965501440.0000, mse_validation=223612030652777350454233268224.0000
# n=186: rmse_train=124264410154737.1406, rmse_validation=472876337590259.8125
# n=186: r2_train=0.9865, r2_validation=0.7866
# n=186: max_error_train=3055744900290522.5000, max_error_validation=6445158078278907.0000
# --- 2.395176887512207 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  187
#
# n=187: mae_train=61861291143728.9688, mae_validation=231229924242697.5312
# n=187: mse_train=15192130822942972916615086080.0000, mse_validation=214650670332200019725954056192.0000
# n=187: rmse_train=123256362200670.8906, rmse_validation=463304079770726.8125
# n=187: r2_train=0.9867, r2_validation=0.7952
# n=187: max_error_train=3050891530588052.5000, max_error_validation=6474546229254702.0000
# --- 2.411191940307617 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  188
#
# n=188: mae_train=62135310472270.4609, mae_validation=240240973227814.1875
# n=188: mse_train=15176628542408859227894317056.0000, mse_validation=214541754088740345561384747008.0000
# n=188: rmse_train=123193459819946.8438, rmse_validation=463186521920425.0000
# n=188: r2_train=0.9868, r2_validation=0.7953
# n=188: max_error_train=2846430532525538.5000, max_error_validation=6011881366972902.0000
# --- 2.2960870265960693 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  189
#
# n=189: mae_train=61817331918324.7344, mae_validation=238815826596668.7188
# n=189: mse_train=14980670748276479024531767296.0000, mse_validation=220060158296454164401577000960.0000
# n=189: rmse_train=122395550361426.4531, rmse_validation=469105700558471.3125
# n=189: r2_train=0.9869, r2_validation=0.7900
# n=189: max_error_train=3098133552625722.5000, max_error_validation=6289790519773702.0000
# --- 2.201000690460205 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  190
#
# n=190: mae_train=61686345280578.8516, mae_validation=227464266814070.2500
# n=190: mse_train=14883210336252440090117144576.0000, mse_validation=211848032722539793403370012672.0000
# n=190: rmse_train=121996763630239.1406, rmse_validation=460269521826657.3125
# n=190: r2_train=0.9870, r2_validation=0.7979
# n=190: max_error_train=2650762059594723.0000, max_error_validation=6173821151192663.0000
# --- 2.2910821437835693 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  191
#
# n=191: mae_train=62096178415888.4375, mae_validation=230943331286775.9688
# n=191: mse_train=15388726497451970030299250688.0000, mse_validation=218174007812679621739196448768.0000
# n=191: rmse_train=124051305907886.2344, rmse_validation=467091005921415.3125
# n=191: r2_train=0.9866, r2_validation=0.7918
# n=191: max_error_train=3008777345944380.5000, max_error_validation=6429836218335653.0000
# --- 2.268062114715576 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  192
#
# n=192: mae_train=62998301036650.7031, mae_validation=235826447013884.3125
# n=192: mse_train=15773459454815640292295704576.0000, mse_validation=220707603617844371411250970624.0000
# n=192: rmse_train=125592433907523.4219, rmse_validation=469795278411612.3750
# n=192: r2_train=0.9862, r2_validation=0.7894
# n=192: max_error_train=2913703396340125.5000, max_error_validation=6160124841580520.0000
# --- 2.4141948223114014 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  193
#
# n=193: mae_train=62302084328449.9531, mae_validation=236872729532467.3125
# n=193: mse_train=15289587580604599930347061248.0000, mse_validation=226791544607854029764403658752.0000
# n=193: rmse_train=123651071894280.7969, rmse_validation=476226358581561.5625
# n=193: r2_train=0.9867, r2_validation=0.7836
# n=193: max_error_train=3010429495988952.0000, max_error_validation=6183346832874982.0000
# --- 2.443220853805542 seconds ---
#
# No. of no improvements:  3
# No. of features considering:  194
#
# n=194: mae_train=61465576579802.4688, mae_validation=241366227825480.0938
# n=194: mse_train=14987807560820977572473995264.0000, mse_validation=222062655839808543002168655872.0000
# n=194: rmse_train=122424701595801.2344, rmse_validation=471235244691872.0625
# n=194: r2_train=0.9869, r2_validation=0.7881
# n=194: max_error_train=3094213853185628.0000, max_error_validation=6233449867817177.0000
# --- 2.459235191345215 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  195
#
# n=195: mae_train=62361694810831.5469, mae_validation=233384028580112.7188
# n=195: mse_train=15337716775814360240928849920.0000, mse_validation=218654903982361654632038531072.0000
# n=195: rmse_train=123845535954326.4219, rmse_validation=467605500376505.0625
# n=195: r2_train=0.9866, r2_validation=0.7914
# n=195: max_error_train=3028753565695799.5000, max_error_validation=6383072182091528.0000
# --- 2.3991808891296387 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  196
#
# n=196: mae_train=62447045747868.5078, mae_validation=223444230569038.6250
# n=196: mse_train=15549845778170939670848864256.0000, mse_validation=218410258798416989924135796736.0000
# n=196: rmse_train=124699020758668.9062, rmse_validation=467343833594086.2500
# n=196: r2_train=0.9864, r2_validation=0.7916
# n=196: max_error_train=2985698001954513.5000, max_error_validation=6500018663148941.0000
# --- 2.3201088905334473 seconds ---
#
# No. of no improvements:  0
# No. of features considering:  197
#
# n=197: mae_train=62512154092988.5938, mae_validation=239982570195231.0312
# n=197: mse_train=15475528826691689293505626112.0000, mse_validation=218493684170606304278454730752.0000
# n=197: rmse_train=124400678562022.6875, rmse_validation=467433079884817.6250
# n=197: r2_train=0.9865, r2_validation=0.7915
# n=197: max_error_train=2913506657554612.5000, max_error_validation=6010511042318519.0000
# --- 2.440218210220337 seconds ---
#
# No. of no improvements:  1
# No. of features considering:  198
#
# n=198: mae_train=61650846494567.3672, mae_validation=235637595563831.8125
# n=198: mse_train=15053582258928672076229246976.0000, mse_validation=222249954899965929523840548864.0000
# n=198: rmse_train=122693040792575.8125, rmse_validation=471433934820103.8750
# n=198: r2_train=0.9869, r2_validation=0.7879
# n=198: max_error_train=2862037211157389.5000, max_error_validation=6113907519442988.0000
# --- 2.3801634311676025 seconds ---
#
# No. of no improvements:  2
# No. of features considering:  199
#
# n=199: mae_train=61475806704929.0938, mae_validation=242908721338837.8438
# n=199: mse_train=15012099978601878644848590848.0000, mse_validation=224685634262812155322740768768.0000
# n=199: rmse_train=122523875137060.0312, rmse_validation=474010162615541.5625
# n=199: r2_train=0.9869, r2_validation=0.7856
# n=199: max_error_train=2962211261714508.5000, max_error_validation=6442742906017412.0000
# --- 2.5012736320495605 seconds ---
#
# No. of no improvements:  3
# No. of features considering:  200
#
# n=200: mae_train=62169946738789.4922, mae_validation=245384730904000.5000
# n=200: mse_train=15388234585075849669556305920.0000, mse_validation=223756712047312758159332868096.0000
# n=200: rmse_train=124049323194751.2500, rmse_validation=473029293011873.3750
# n=200: r2_train=0.9866, r2_validation=0.7865
# n=200: max_error_train=3216308135933024.0000, max_error_validation=6311616020562941.0000
# --- 2.3941760063171387 seconds ---
#
# No. of no improvements:  0
# Terminated: max. no. of iterations reached
# Result saved as: GBFS_result_p_conductivity.pkl
#                    train_mae        va_mae     train_mse        va_mse  \
# no_of_features
# 1               3.305985e+14  3.234058e+14  6.008664e+29  5.997353e+29
# 2               2.686389e+14  3.101667e+14  4.132090e+29  6.477056e+29
# 3               2.138218e+14  2.942401e+14  2.544126e+29  6.025337e+29
# 4               1.939621e+14  2.777074e+14  2.105446e+29  5.098224e+29
# 5               1.582177e+14  5.057765e+14  1.283023e+29  1.030985e+30
# ...                      ...           ...           ...           ...
# 195             6.236169e+13  2.333840e+14  1.533772e+28  2.186549e+29
# 196             6.244705e+13  2.234442e+14  1.554985e+28  2.184103e+29
# 197             6.251215e+13  2.399826e+14  1.547553e+28  2.184937e+29
# 198             6.165085e+13  2.356376e+14  1.505358e+28  2.222500e+29
# 199             6.147581e+13  2.429087e+14  1.501210e+28  2.246856e+29
#
#                   train_rmse       va_rmse  train_r_sq   va_r_sq  \
# no_of_features
# 1               7.751557e+14  7.744258e+14    0.475720  0.427727
# 2               6.428134e+14  8.048016e+14    0.639459  0.381954
# 3               5.043933e+14  7.762304e+14    0.778015  0.425057
# 4               4.588514e+14  7.140185e+14    0.816291  0.513523
# 5               3.581931e+14  1.015374e+15    0.888051  0.016225
# ...                      ...           ...         ...       ...
# 195             1.238455e+14  4.676055e+14    0.986617  0.791358
# 196             1.246990e+14  4.673438e+14    0.986432  0.791591
# 197             1.244007e+14  4.674331e+14    0.986497  0.791511
# 198             1.226930e+14  4.714339e+14    0.986865  0.787927
# 199             1.225239e+14  4.740102e+14    0.986901  0.785603
#
#                 train_max_error  va_max_error
# no_of_features
# 1                  9.033899e+15  8.864208e+15
# 2                  8.783319e+15  9.645423e+15
# 3                  7.544328e+15  8.080561e+15
# 4                  7.511739e+15  8.166210e+15
# 5                  6.012706e+15  7.477898e+15
# ...                         ...           ...
# 195                3.028754e+15  6.383072e+15
# 196                2.985698e+15  6.500019e+15
# 197                2.913507e+15  6.010511e+15
# 198                2.862037e+15  6.113908e+15
# 199                2.962211e+15  6.442743e+15
#
# [199 rows x 10 columns]

# %%
# Plot the result
FS.convergence_plot()
# Out:
# Result saved as: GBFS_convergence_plot_p_conductivity.png

# %%
# Plot the result
FS.convergence_plot(
                    train_metric = 'train_rmse',
                    validation_metric = 'va_rmse'
                    )
# Out:
# Result saved as: GBFS_convergence_plot_p_conductivity.png

# %%
# Plot the result
FS.convergence_plot(
                    train_metric = 'train_mae',
                    validation_metric = 'va_mae'
                    )
# Out:
# Result saved as: GBFS_convergence_plot_p_conductivity.png

# %%
# Plot the result
FS.convergence_plot(
                    train_metric = 'train_r_sq',
                    validation_metric = 'va_r_sq'
                    )
# Out:
# Result saved as: GBFS_convergence_plot_p_conductivity.png

# %%
# # Plot the result
# FS.convergence_plot(
#                     train_metric = ['train_r_sq', 'train_rmse', 'train_mae'],
#                     validation_metric = ['va_r_sq', 'va_rmse', 'va_mae']
#                     )

# %% [markdown]
# ##### Statistical Analyses - Regression

# %%
import sys
sys.path.insert(1, 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties')

import feature_analyses as fa

import joblib
import pandas as pd
import numpy as np

# %%
# Target
target = 'p_conductivity'

# Path to training data
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'
path_to_file = path_to_save + 'df_train_' + target + '_scaled.pkl'

# Either a list or saved file
features = path + 'features_v2.pkl'

problem = 'regression'

# %%
# Initialization 
analyses = fa.perform(
                    path_to_file = path_to_file, 
                    path_to_save = path_to_save, 
                    target = target,
                    features = features
                    )
# Out:
# Name of target column:  p_conductivity
# No. of exploratory features:  2497

# %%
df = analyses.remove_constant_features()
df.head()
# Out:
# No. of features removed:  38
# No. of exploratory features:  2459
#            compound_possible  max_ionic_char  avg_ionic_char      H   He   Li  \
# mp-569760                0.0        0.287702        0.269721  0.000  0.0  0.0
# mp-766452                1.0        0.809174        0.772548  0.000  0.0  0.0
# mp-795616                0.0        0.593746        0.543455  0.000  0.0  0.0
# mp-761614                0.0        0.494632        0.376445  0.000  0.0  0.0
# mp-27235                 1.0        0.593746        0.322122  0.625  0.0  0.0
#
#             Be    B    C     N  ...  LUMO_element_ohe_Zn  LUMO_element_ohe_Zr  \
# mp-569760  0.0  0.0  0.0  0.00  ...                  0.0                  0.0
# mp-766452  0.0  0.0  0.0  0.00  ...                  0.0                  0.0
# mp-795616  0.0  0.0  0.0  0.00  ...                  0.0                  0.0
# mp-761614  0.0  0.0  0.0  0.00  ...                  0.0                  0.0
# mp-27235   0.0  0.0  0.0  0.25  ...                  0.0                  0.0
#
#            crystal_system_ohe_cubic  crystal_system_ohe_hexagonal  \
# mp-569760                       0.0                           1.0
# mp-766452                       0.0                           0.0
# mp-795616                       0.0                           0.0
# mp-761614                       0.0                           0.0
# mp-27235                        0.0                           0.0
#
#            crystal_system_ohe_monoclinic  crystal_system_ohe_orthorhombic  \
# mp-569760                            0.0                              0.0
# mp-766452                            0.0                              0.0
# mp-795616                            0.0                              0.0
# mp-761614                            1.0                              0.0
# mp-27235                             0.0                              1.0
#
#            crystal_system_ohe_tetragonal  crystal_system_ohe_triclinic  \
# mp-569760                            0.0                           0.0
# mp-766452                            0.0                           1.0
# mp-795616                            0.0                           0.0
# mp-761614                            0.0                           0.0
# mp-27235                             0.0                           0.0
#
#            crystal_system_ohe_trigonal  p_conductivity
# mp-569760                          0.0    3.602017e+14
# mp-766452                          0.0    9.129843e+13
# mp-795616                          1.0    3.334941e+10
# mp-761614                          0.0    6.949018e+13
# mp-27235                           0.0    1.787985e+10
#
# [5 rows x 2460 columns]

# %%
df_anova = analyses.ANOVA_F_test(
                                problem='regression', 
                                all_features=False, 
                                csv=False
                                )

df_anova
# Out:
# There are:
# No. of categorical features:  187
# No. of numerical features:  2272
#
# Considering only the numerical features.
#
# Result saved as:  ANOVA_F_test_result_p_conductivity_regression.pkl
#                               feature_names   f_statistic  f_statistic_scaled
# 0              MagpieData_maximum_NpValence  1.869339e+04        1.000000e+00
# 1                    max_packing_efficiency  1.757034e+04        9.399227e-01
# 2     MEGNetElementData_minimum_embedding_7  1.601873e+04        8.569197e-01
# 3                MagpieData_range_NpValence  1.517146e+04        8.115950e-01
# 4         PymatgenData_maximum_mendeleev_no  1.503588e+04        8.043421e-01
# ...                                     ...           ...                 ...
# 2267                    jml_mean_charge_267  2.624510e-04        1.402249e-08
# 2268                              jml_nn_39  1.654346e-05        8.677010e-10
# 2269         PymatgenData_range_atomic_mass  1.644423e-05        8.623927e-10
# 2270          MagpieData_range_AtomicWeight  1.041311e-05        5.397592e-10
# 2271                       jml_is_noble_gas  3.231851e-07        0.000000e+00
#
# [2272 rows x 3 columns]

# %%
df_mi = analyses.mutual_information(
                                problem='regression', 
                                csv=False
                                )

df_mi
# Out:
# There are:
# No. of categorical features:  187
# No. of numerical features:  2272
#
# Result saved as: MI_result_p_conductivity.pkl
#                          feature_names        MI  MI_scaled
# 0     jml_first_ion_en_divi_therm_cond  0.515877   1.000000
# 1       jml_voro_coord_divi_therm_cond  0.509716   0.988058
# 2          jml_mol_vol_divi_therm_cond  0.504545   0.978034
# 3         jml_atom_rad_divi_therm_cond  0.503345   0.975708
# 4             jml_first_ion_en_divi_bp  0.486833   0.943700
# ...                                ...       ...        ...
# 2441                LUMO_element_ohe_W  0.000000   0.000000
# 2439               HOMO_element_ohe_Er  0.000000   0.000000
# 2438                       Ar_fraction  0.000000   0.000000
# 2437                                Ar  0.000000   0.000000
# 2458                         jml_rdf_7  0.000000   0.000000
#
# [2459 rows x 3 columns]

# %% [markdown]
# #### Feature Engineering

# %%
import sys
sys.path.insert(1, 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties')

import feature_engineering as fe

import joblib
import pandas as pd
import numpy as np

# %%
# Target
target = 'p_conductivity'

# Path to training data
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'
path_to_file = path + 'ricci_boltztrap_mp_tabular_merged_with_NaN_v2_ptype_.pkl'  # all data

# Either a list or saved file for the features
features = path + 'features.pkl'

problem = 'regression'

# %%
# Top n features from ANOVA 
df_anova = joblib.load(path_to_save + 'ANOVA_F_test_result_' + target + '_regression.pkl')

# Top n features
n = 5
anova_features = df_anova['feature_names'].tolist()[:n]

df_anova.iloc[:n, :]
# Out:
#                            feature_names   f_statistic  f_statistic_scaled
# 0           MagpieData_maximum_NpValence  18693.389758            1.000000
# 1                 max_packing_efficiency  17570.341316            0.939923
# 2  MEGNetElementData_minimum_embedding_7  16018.733429            0.856920
# 3             MagpieData_range_NpValence  15171.461711            0.811595
# 4      PymatgenData_maximum_mendeleev_no  15035.879990            0.804342

# %%
# Top n features from MI 
df_mi = joblib.load(path_to_save + 'MI_result_' + target + '.pkl')

# Top n features
n = 5
mi_features = df_mi['feature_names'].tolist()[:n]

df_mi.iloc[:n, :]
# Out:
#                       feature_names        MI  MI_scaled
# 0  jml_first_ion_en_divi_therm_cond  0.515877   1.000000
# 1    jml_voro_coord_divi_therm_cond  0.509716   0.988058
# 2       jml_mol_vol_divi_therm_cond  0.504545   0.978034
# 3      jml_atom_rad_divi_therm_cond  0.503345   0.975708
# 4          jml_first_ion_en_divi_bp  0.486833   0.943700

# %%
# Top n features from GBFS
df_gbfs = joblib.load(path_to_save + 'feature_relevance_score_' + target + '.pkl')

# Top n features
n = 5
gbfs_features = df_gbfs['feature'].tolist()[:n]

df_gbfs.iloc[:n, :]
# Out:
#                                      feature  relevance_score
# 0                     max_packing_efficiency     5.670610e+34
# 1  PymatgenData_minimum_thermal_conductivity     1.133036e+34
# 2                                    total_e     8.013354e+33
# 3         MagpieData_maximum_MendeleevNumber     4.597238e+33
# 4                                    jml_vpa     2.829331e+33

# %%
# Initialization
perform = fe.engineering(
                        path_to_file = path_to_file, 
                        path_to_save = path_to_save, 
                        target = target,
                        features = features
                        )
# Out:
# Name of target column:  p_conductivity
# No. of exploratory features:  2368

# %%
# Join the features
feature_list = anova_features + mi_features + gbfs_features

print(len(feature_list))
print(feature_list)
# Out:
# 15
# ['MagpieData_maximum_NpValence', 'max_packing_efficiency', 'MEGNetElementData_minimum_embedding_7', 'MagpieData_range_NpValence', 'PymatgenData_maximum_mendeleev_no', 'jml_first_ion_en_divi_therm_cond', 'jml_voro_coord_divi_therm_cond', 'jml_mol_vol_divi_therm_cond', 'jml_atom_rad_divi_therm_cond', 'jml_first_ion_en_divi_bp', 'max_packing_efficiency', 'PymatgenData_minimum_thermal_conductivity', 'total_e', 'MagpieData_maximum_MendeleevNumber', 'jml_vpa']

# %%
# Perform feature engineering
df, new_cols = perform.brute_force(feature_list = feature_list)

df.head()
# Out:
# Total number of permutation: 210
# Invalid operations: 27
#            minimum_oxidation_state  maximum_oxidation_state  \
# mp-1992                        0.0                      0.0
# mp-27502                       0.0                      0.0
# mp-770629                      0.0                      0.0
# mp-27202                       0.0                      0.0
# mp-559608                      0.0                      0.0
#
#            range_oxidation_state  std_dev_oxidation_state  compound_possible  \
# mp-1992                      0.0                      0.0                  0
# mp-27502                     0.0                      0.0                  1
# mp-770629                    0.0                      0.0                  1
# mp-27202                     0.0                      0.0                  0
# mp-559608                    0.0                      0.0                  1
#
#            max_ionic_char  avg_ionic_char  avg_anion_electron_affinity  \
# mp-1992          0.190712        0.044698                          0.0
# mp-27502         0.088829        0.016742                          0.0
# mp-770629        0.779730        0.171021                          0.0
# mp-27202         0.070306        0.004246                          0.0
# mp-559608        0.820234        0.145225                          0.0
#
#            minimum_EN_difference  maximum_EN_difference  ...  \
# mp-1992                      0.0                    0.0  ...
# mp-27502                     0.0                    0.0  ...
# mp-770629                    0.0                    0.0  ...
# mp-27202                     0.0                    0.0  ...
# mp-559608                    0.0                    0.0  ...
#
#            jml_vpa/PymatgenData_maximum_mendeleev_no  \
# mp-1992                                     0.000000
# mp-27502                                    0.014111
# mp-770629                                   0.029935
# mp-27202                                    0.010531
# mp-559608                                   0.017209
#
#            jml_vpa/jml_first_ion_en_divi_therm_cond  \
# mp-1992                                    0.000000
# mp-27502                                   0.002096
# mp-770629                                  0.023596
# mp-27202                                   0.025790
# mp-559608                                  0.013559
#
#            jml_vpa/jml_voro_coord_divi_therm_cond  \
# mp-1992                                  0.000000
# mp-27502                                 0.007485
# mp-770629                                0.106873
# mp-27202                                 0.089604
# mp-559608                                0.061145
#
#            jml_vpa/jml_mol_vol_divi_therm_cond  \
# mp-1992                               0.000000
# mp-27502                              0.001708
# mp-770629                             0.018509
# mp-27202                              0.023380
# mp-559608                             0.010617
#
#            jml_vpa/jml_atom_rad_divi_therm_cond  \
# mp-1992                                0.000000
# mp-27502                               0.030781
# mp-770629                              0.534812
# mp-27202                               0.516989
# mp-559608                              0.306126
#
#            jml_vpa/jml_first_ion_en_divi_bp  \
# mp-1992                            0.000000
# mp-27502                          17.297968
# mp-770629                         76.071359
# mp-27202                           4.737261
# mp-559608                         43.620105
#
#            jml_vpa/PymatgenData_minimum_thermal_conductivity  jml_vpa/total_e  \
# mp-1992                                             0.000000         0.000000
# mp-27502                                          158.550286         0.023518
# mp-770629                                         113.749360         0.009816
# mp-27202                                            6.009646         0.003930
# mp-559608                                          65.392952         0.001238
#
#            jml_vpa/MagpieData_maximum_MendeleevNumber  p_conductivity
# mp-1992                                      0.000000    1.133147e+14
# mp-27502                                     0.015012    3.114487e+10
# mp-770629                                    0.034752    1.224568e+10
# mp-27202                                     0.011791    2.413099e+09
# mp-559608                                    0.019979    8.818485e+08
#
# [5 rows x 2723 columns]

# %%
perform.save()
# Out:
# Result saved as: df_p_conductivity_engineered_features.pkl
# Result saved as: features_p_conductivity_engineered.pkl
# Result saved as: df_train_p_conductivity_engineered.pkl
# Result saved as: df_test_p_conductivity_engineered.pkl

# %% [markdown]
# #### Multi-Collinearity Reduction

# %%
import sys
sys.path.insert(1, 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties')

import multicollinearity_reduction as mr

import joblib
import pandas as pd
import numpy as np

# %%
# Target
target = 'p_conductivity' 

# Path to training data
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'
path_to_file = path_to_save + 'df_train_' + target + '_engineered.pkl'

# Features 
n = 125 # Most relevant features defined using the GBFS result

gbfs_cols = joblib.load(path_to_save + 'feature_relevance_score_' + target + '.pkl')['feature'].tolist()[:n]
new_cols = joblib.load(path_to_save + 'features_' + target + '_engineered.pkl')
features = gbfs_cols + new_cols

problem = 'regression'

print(len(gbfs_cols))
print(len(new_cols))
len(features)
# Out:
# 125
# 183
# 308

# %%
# Initialize module with path_to_file and path_to_save
data = mr.multicollinearity_reduction(
                                        path_to_file, 
                                        path_to_save, 
                                        target=target,
                                        features = features 
                                        )
# Out:
# Name of target column:  p_conductivity
# No. of exploratory features:  308

# %%
# Remove features with correlation coeff greather than the threshold
col_corr = data.correlation_analysis(threshold = 0.85)
new_features = data.apply_correlation_filter()
# Out:
# Identified correlated features
# No. of features remaining:  154
# Features saved as: features_selected_from_correlation_analysis_p_conductivity.pkl

# %%
# Perform hierarchical cluster analysis & create the corresponding dendrogram 
data.hierarchical_cluster_analysis()
# Out:
# c:\Users\songy\miniconda3\envs\gbfs\lib\site-packages\numpy\lib\function_base.py:2559: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# c:\Users\songy\miniconda3\envs\gbfs\lib\site-packages\numpy\lib\function_base.py:2560: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# Figure saved as: Dendrogram_p_conductivity.png

# %%
# Select features based on the given linkage threshold
threshold_list = [1, 2, 3, 4, 5, 6]

for i in threshold_list:
    final_features = data.apply_linkage_threshold(threshold = i)
# Out:
# Number of features remaining:  136
# Features saved as features_selected_from_hierarchical_analysis_p_conductivity_threshold_1.pkl
# Number of features remaining:  73
# Features saved as features_selected_from_hierarchical_analysis_p_conductivity_threshold_2.pkl
# Number of features remaining:  41
# Features saved as features_selected_from_hierarchical_analysis_p_conductivity_threshold_3.pkl
# Number of features remaining:  24
# Features saved as features_selected_from_hierarchical_analysis_p_conductivity_threshold_4.pkl
# Number of features remaining:  18
# Features saved as features_selected_from_hierarchical_analysis_p_conductivity_threshold_5.pkl
# Number of features remaining:  12
# Features saved as features_selected_from_hierarchical_analysis_p_conductivity_threshold_6.pkl

# %% [markdown]
# #### Recursive Feature Elimination

# %%
import sys
sys.path.insert(1, 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties')

import recursive_feature_elimination as rfe

import joblib
import pandas as pd

# %%
# Target
target = 'p_conductivity' 

# Path to training data
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'
path_to_file = path_to_save + 'df_train_' + target + '_engineered.pkl'

# Features 
features = joblib.load(path_to_save + 'features_selected_from_hierarchical_analysis_' + target + '_threshold_2.pkl')

scaled = False

problem = 'regression'

# %%
# Initialize module with path_to_file and path_to_save
run = rfe.recursive_feature_elimination(
                                        path_to_file, 
                                        path_to_save, 
                                        target=target,
                                        features = features,
                                        scaled = False,
                                        problem = problem
                                        )
# Out:
# Target: p_conductivity
# No. of features: 73

# %%
# Run RFE
estimator = run.base_model(boosting_method = 'lightGBM')
RFE_features = run.perform()
# Out:
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# Fitting estimator with 54 features.
# Grid scores saved: RFECV_features_grid_scores_p_conductivity.pkl
#
#  Features saved as features_selected_from_RFE_p_conductivity.pkl
#
#  Number of features remaining:  53

# %%
# Plot figure
run.RFE_plot()
# Out:
# Figure saved as: RFE_plot_p_conductivity.png

# %% [markdown]
# #### Test Dummy Model

# %%
### test result to find best threshold

import pandas as pd
import numpy as np
import joblib
import statsmodels.api as sm
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, max_error
from sklearn.metrics import explained_variance_score,mean_squared_error
from sklearn.preprocessing import MinMaxScaler

from lightgbm.sklearn import LGBMRegressor

# %%
# Target
target = 'p_conductivity' 

# Path to training data
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'
path_to_file = path_to_save + 'df_train_' + target + '_engineered.pkl'

# Data
df_train = joblib.load(path_to_save + 'df_train_' + target + '_engineered.pkl')
df_test = joblib.load(path_to_save + 'df_test_' + target + '_engineered.pkl')

# Features 
features = joblib.load(path_to_save + 'features_selected_from_hierarchical_analysis_' + target + '_threshold_2.pkl')
scaled = False
print('No. of features:', len(features))

problem = 'regression'
# Out:
# No. of features: 73

# %%
# Scale the features
scaling = MinMaxScaler(feature_range=(0, 1))

df_train[features] = pd.DataFrame(
                                    scaling.fit_transform(df_train[features].values),
                                    columns=df_train[features].columns,
                                    index=df_train[features].index
                                )
                                

df_test[features] = pd.DataFrame(
                                    scaling.transform(df_test[features].values),
                                    columns=df_test[features].columns,
                                    index=df_test[features].index
                                )

# %%
lgbm = LGBMRegressor(
                    boosting_type ='gbdt',
                    objective='regression',
                    importance_type='gain',
                    learning_rate=0.1,
                    n_estimators=350,
                    num_leaves=40,
                    max_depth=-1,
                    random_state=42
                    )

lgbm.fit(df_train[features], df_train[target].values.ravel())
lgbm
# Out:
# LGBMRegressor(importance_type='gain', n_estimators=350, num_leaves=40,
#               objective='regression', random_state=42)

# %%
# Predict
predicted_target = lgbm.predict(df_test[features])

# Generate table of results
id_index = df_test.index.tolist()

df_pred = pd.DataFrame({'task_id': id_index,
                        'act_target': df_test[target].values.reshape(1, -1).ravel(),
                        'pred_target': predicted_target
                        })
df_pred['adj_pred_target'] = df_pred['pred_target']
df_pred['adj_pred_target'] = df_pred['adj_pred_target'].apply(lambda x: 0 if x < 0 else x)

# Define variables
y_test = df_pred['act_target']
y_pred_adj = df_pred['adj_pred_target']
y_pred = df_pred['pred_target']

# %%
print('Max value:', df_test[target].max())
print('Min value:', df_test[target].min())
# Out:
# Max value: 9855520678802140.0
# Min value: 134061.44346344474

# %%
def plot(df_pred, adj=False):
        # Plot results
        max_value = 9999123921578508
        min_value = 0

        X = df_pred['act_target']
        if adj is True:
                Y = df_pred['adj_pred_target']
        else:
                Y = df_pred['pred_target']

        # Stats
        results = sm.OLS(Y,sm.add_constant(X)).fit()
        print(results.summary())

        # Figure
        fig = plt.figure(figsize=(10, 10)) #, dpi=100, facecolor='w', edgecolor='k')
        gs = GridSpec(4, 4)

        ax_scatter = fig.add_subplot(gs[1:4, 0:3])
        ax_hist_y = fig.add_subplot(gs[0,0:3])
        ax_hist_x = fig.add_subplot(gs[1:4, 3])


        fontsize = 18

        # Predicted vs Actual
        ax_scatter.plot(X, Y, 'o', markersize=6, color='black', alpha=0.12)

        offset = 0.15
        # line of best fit
        linear_fit = np.linspace(min_value-offset, max_value-offset, 10)
        ax_scatter.plot(linear_fit, linear_fit*results.params[1] + results.params[0], '-.', color='tab:blue', alpha=0.7)

        # Ideal y=x 
        y = x = np.linspace(min_value-offset, max_value-offset, 10)
        ax_scatter.plot(x, y, '--', color='red', alpha=0.7)

        ticks = np.linspace(min_value, max_value, 5)

        onset = -100000000000
        ax_scatter.set_xlabel('DFT Calculation of Hole Conductivity', fontsize=fontsize)
        ax_scatter.set_ylabel('ML Prediction of Hole Conductivity', fontsize=fontsize)
        ax_scatter.tick_params(axis='both', which='both', labelsize=fontsize, direction="in")
        ax_scatter.set_xlim(min_value-onset, max_value+onset)
        ax_scatter.set_ylim(min_value-onset, max_value+onset)
        ax_scatter.set_xticks(ticks)
        ax_scatter.set_yticks(ticks)

        ax_hist_x.tick_params(axis='both', which='both', labelsize=fontsize, direction="in", labelleft=False)
        ax_hist_x.set_xlabel('Count', fontsize=fontsize)
        ax_hist_x.set_ylim(min_value-onset, max_value+onset)
        ax_hist_x.set_xticks([0, 2500, 5000])
        ax_hist_x.set_yticks(ticks)

        ax_hist_y.tick_params(axis='both', which='both', labelsize=fontsize, direction="in", labelbottom=False)
        ax_hist_y.set_ylabel('Count', fontsize=fontsize)
        ax_hist_y.set_xlim(min_value-onset, max_value+onset)
        ax_hist_y.set_yticks([0, 2000, 4000])
        ax_hist_y.set_xticks(ticks)

        # Distribution plots
        alpha = 0.4
        histtype = 'bar' #'step' bar
        color = 'black' #'tab:grey'
        bins = 60 #70

        ax_hist_y.hist(
                        y_pred_adj, 
                        bins=bins, 
                        color=color, 
                        histtype=histtype,
                        alpha=alpha
                        )
        ax_hist_x.hist(
                        y_test, 
                        orientation='horizontal', 
                        bins=bins, 
                        color=color, 
                        histtype=histtype,
                        alpha=alpha
                        )


        #Text in figure
        font1 = {'family': 'DejaVu Sans',
                'color':  'red',
                'weight': 'normal',
                'size': fontsize-3,
                }

        font2 = {'family': 'DejaVu Sans',
                'color':  'tab:blue',
                'weight': 'normal',
                'size': fontsize-3,
                }

        font3 = {'family': 'DejaVu Sans', #'serif',
                'color':  'black',
                'weight': 'normal',
                'size': fontsize-3,
                }
        
        plt.show()

        print('m = ', results.params[1])
        print('c = ', results.params[0], '\n')

        print('MAE: ', mean_absolute_error(X, Y))
        print('MSE: ', mean_squared_error(X, Y))
        print('RMSE: ', mean_squared_error(X, Y, squared=False))
        print('R-squared: ', r2_score(X, Y))
        print('Max error: ', max_error(X, Y))
        print('Explained_variance_score: ', explained_variance_score(X, Y, multioutput='variance_weighted'))

# %%
plot(df_pred, adj=False)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pred_target   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                 4.452e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:01:02   Log-Likelihood:            -3.3329e+05
# No. Observations:                9514   AIC:                         6.666e+05
# Df Residuals:                    9512   BIC:                         6.666e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.661e-16   1.15e-18    231.979      0.000    2.64e-16    2.68e-16
# act_target     0.8457      0.004    231.979      0.000       0.839       0.853
# ==============================================================================
# Omnibus:                     5574.191   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1035105.188
# Skew:                           1.742   Prob(JB):                         0.00
# Kurtosis:                      53.981   Cond. No.                     1.19e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.19e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
# m =  0.8456671507294252
# c =  2.66054904262564e-16
#
# MAE:  163507704816045.0
# MSE:  1.862348798358203e+29
# RMSE:  431549394433383.8
# R-squared:  0.8287617482944143
# Max error:  6816989008334447.0
# Explained_variance_score:  0.8287630493020695

# %%
import seaborn as sns

# Generate feature ranking
model = lgbm

feature_score = pd.DataFrame({'feature': features, 'relevance_score': model.feature_importances_})
feature_score = feature_score.sort_values(by = 'relevance_score', ascending = False)
feature_score = feature_score.reset_index(drop = True)


#Plot data of feature relevance 
sns.set(rc = {'figure.figsize':(10, 10)})

# Number of features to plot
no_of_features = 20

fig = sns.barplot(x = 'relevance_score', y = 'feature', data = feature_score[:no_of_features])
fig.set(xlabel = 'Relevance score', ylabel = 'Feature')
# Out:
# [Text(0.5, 0, 'Relevance score'), Text(0, 0.5, 'Feature')]

# %% [markdown]
# #### Bayesian Optimization

# %%
import sys
sys.path.insert(1, 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties')

import optimization as opt

import joblib
import pandas as pd
import numpy as np

# %%
# Target
target = 'conductivity' 

# Path
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'

# Path to training data
path_to_train_data = path_to_save + 'df_train_' + target + '_engineered.pkl'
path_to_test_data = path_to_save + 'df_test_' + target + '_engineered.pkl'

path_to_features = path_to_save + 'features_selected_from_RFE_' + target + '.pkl' 

problem = 'regression'

scaled = False

# %%
# Initialization
final_stage = opt.optimization(
                            path_to_train_data = path_to_train_data,
                            path_to_test_data = path_to_test_data,
                            path_to_save = path_to_save,
                            features = path_to_features,
                            target = target,
                            problem = problem,
                            scaled = scaled
                            )
# Out:
# Name of target column:  conductivity
# No. of exploratory features:  43

# %%
# Choose ML model
final_stage.base_model(boosting_method = 'lightGBM')
# Out:
# LGBMRegressor(importance_type='gain', random_state=42)

# %%
# Define hyperparameters; range should be edited directly from the script
final_stage.set_hyperparameters()
# Out:
# (['learning_rate', 'n_estimators', 'num_leaves'],
#  [Real(low=0.01, high=1.0, prior='log-uniform', transform='identity'),
#   Integer(low=100, high=800, prior='uniform', transform='identity'),
#   Integer(low=10, high=100, prior='uniform', transform='identity')])

# %%
# optimization_method: dummy_minimize, gp_minimize, gbrt_minimize, forest_minimize
final_stage.run(optimization_method = 'bayesian')
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#
#  {'learning_rate': 0.049679279842082605, 'n_estimators': 431, 'num_leaves': 46}
#
# Score:  509056162604327.8
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 5.5000
# Function value obtained: 509056162604327.8125
# Current minimum: 509056162604327.8125
# Iteration No: 2 started. Evaluating function at random point.
#
#  {'learning_rate': 0.09661170388639592, 'n_estimators': 415, 'num_leaves': 46}
#
# Score:  505471712030470.4
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 3.9062
# Function value obtained: 505471712030470.3750
# Current minimum: 505471712030470.3750
# Iteration No: 3 started. Evaluating function at random point.
#
#  {'learning_rate': 0.1798377857494902, 'n_estimators': 198, 'num_leaves': 90}
#
# Score:  514962215380685.9
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 3.2459
# Function value obtained: 514962215380685.8750
# Current minimum: 505471712030470.3750
# Iteration No: 4 started. Evaluating function at random point.
#
#  {'learning_rate': 0.2013970889531798, 'n_estimators': 683, 'num_leaves': 59}
#
# Score:  516681770472916.5
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 5.7522
# Function value obtained: 516681770472916.5000
# Current minimum: 505471712030470.3750
# Iteration No: 5 started. Evaluating function at random point.
#
#  {'learning_rate': 0.010381867482168546, 'n_estimators': 361, 'num_leaves': 74}
#
# Score:  554313935386414.9
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 4.6809
# Function value obtained: 554313935386414.8750
# Current minimum: 505471712030470.3750
# Iteration No: 6 started. Evaluating function at random point.
#
#  {'learning_rate': 0.042708135248696225, 'n_estimators': 392, 'num_leaves': 76}
#
# Score:  508086966305284.7
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 3.4181
# Function value obtained: 508086966305284.6875
# Current minimum: 505471712030470.3750
# Iteration No: 7 started. Evaluating function at random point.
#
#  {'learning_rate': 0.010891267306975436, 'n_estimators': 373, 'num_leaves': 97}
#
# Score:  542919699714263.5
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 4.0116
# Function value obtained: 542919699714263.5000
# Current minimum: 505471712030470.3750
# Iteration No: 8 started. Evaluating function at random point.
#
#  {'learning_rate': 0.371748934043051, 'n_estimators': 330, 'num_leaves': 42}
#
# Score:  544730848052506.8
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 1.9668
# Function value obtained: 544730848052506.8125
# Current minimum: 505471712030470.3750
# Iteration No: 9 started. Evaluating function at random point.
#
#  {'learning_rate': 0.012381229006041036, 'n_estimators': 181, 'num_leaves': 24}
#
# Score:  647197702099196.9
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 1.0840
# Function value obtained: 647197702099196.8750
# Current minimum: 505471712030470.3750
# Iteration No: 10 started. Evaluating function at random point.
#
#  {'learning_rate': 0.6253877919263049, 'n_estimators': 234, 'num_leaves': 22}
#
# Score:  601326272188500.6
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.2812
# Function value obtained: 601326272188500.6250
# Current minimum: 505471712030470.3750
# Iteration No: 11 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0935449579367676, 'n_estimators': 419, 'num_leaves': 47}
#
# Score:  503308800160203.4
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 2.8216
# Function value obtained: 503308800160203.3750
# Current minimum: 503308800160203.3750
# Iteration No: 12 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.6223601525148685, 'n_estimators': 445, 'num_leaves': 100}
#
# Score:  621203486368765.1
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 4.4871
# Function value obtained: 621203486368765.1250
# Current minimum: 503308800160203.3750
# Iteration No: 13 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.09011325071773993, 'n_estimators': 413, 'num_leaves': 48}
#
# Score:  503398787511079.8
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 2.7705
# Function value obtained: 503398787511079.8125
# Current minimum: 503308800160203.3750
# Iteration No: 14 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.08022238786138011, 'n_estimators': 425, 'num_leaves': 59}
#
# Score:  505877611873078.3
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 3.4281
# Function value obtained: 505877611873078.3125
# Current minimum: 503308800160203.3750
# Iteration No: 15 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.1140992708221739, 'n_estimators': 358, 'num_leaves': 67}
#
# Score:  505423210342086.3
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 3.0668
# Function value obtained: 505423210342086.3125
# Current minimum: 503308800160203.3750
# Iteration No: 16 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.01608614518717733, 'n_estimators': 551, 'num_leaves': 100}
#
# Score:  517311432075312.4
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 6.1806
# Function value obtained: 517311432075312.3750
# Current minimum: 503308800160203.3750
# Iteration No: 17 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.11762421602694563, 'n_estimators': 407, 'num_leaves': 10}
#
# Score:  537025641735039.2
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 1.6015
# Function value obtained: 537025641735039.1875
# Current minimum: 503308800160203.3750
# Iteration No: 18 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.030971462059364213, 'n_estimators': 448, 'num_leaves': 100}
#
# Score:  507885980906052.3
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 5.0068
# Function value obtained: 507885980906052.3125
# Current minimum: 503308800160203.3750
# Iteration No: 19 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.12311616721170265, 'n_estimators': 100, 'num_leaves': 58}
#
# Score:  523372999044209.1
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 1.2081
# Function value obtained: 523372999044209.1250
# Current minimum: 503308800160203.3750
# Iteration No: 20 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.08860195459805453, 'n_estimators': 538, 'num_leaves': 46}
#
# Score:  501745545768241.6
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 3.5292
# Function value obtained: 501745545768241.6250
# Current minimum: 501745545768241.6250
# Iteration No: 21 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.08321088438999515, 'n_estimators': 577, 'num_leaves': 46}
#
# Score:  502467857139474.1
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 3.7284
# Function value obtained: 502467857139474.1250
# Current minimum: 501745545768241.6250
# Iteration No: 22 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.03346306527486385, 'n_estimators': 702, 'num_leaves': 67}
#
# Score:  503554715825980.7
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 5.6311
# Function value obtained: 503554715825980.6875
# Current minimum: 501745545768241.6250
# Iteration No: 23 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.1022323568397918, 'n_estimators': 542, 'num_leaves': 47}
#
# Score:  505737311842493.6
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 3.3951
# Function value obtained: 505737311842493.6250
# Current minimum: 501745545768241.6250
# Iteration No: 24 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.06349413943180508, 'n_estimators': 598, 'num_leaves': 48}
#
# Score:  499931766541812.1
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 3.9267
# Function value obtained: 499931766541812.1250
# Current minimum: 499931766541812.1250
# Iteration No: 25 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.059649741422737185, 'n_estimators': 695, 'num_leaves': 46}
#
# Score:  502083143010175.2
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 4.3471
# Function value obtained: 502083143010175.1875
# Current minimum: 499931766541812.1250
# Iteration No: 26 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.035078380240916016, 'n_estimators': 732, 'num_leaves': 92}
#
# Score:  500808448791943.1
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 7.1595
# Function value obtained: 500808448791943.1250
# Current minimum: 499931766541812.1250
# Iteration No: 27 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.05352715216731619, 'n_estimators': 593, 'num_leaves': 100}
#
# Score:  505381557665904.6
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 6.2527
# Function value obtained: 505381557665904.6250
# Current minimum: 499931766541812.1250
# Iteration No: 28 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.02880516946718103, 'n_estimators': 800, 'num_leaves': 91}
#
# Score:  501239548351685.5
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 7.7631
# Function value obtained: 501239548351685.5000
# Current minimum: 499931766541812.1250
# Iteration No: 29 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.058057747176926765, 'n_estimators': 629, 'num_leaves': 56}
#
# Score:  501582468335603.7
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 4.4570
# Function value obtained: 501582468335603.6875
# Current minimum: 499931766541812.1250
# Iteration No: 30 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.03345695422880104, 'n_estimators': 693, 'num_leaves': 86}
#
# Score:  503485444285572.0
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 6.6150
# Function value obtained: 503485444285572.0000
# Current minimum: 499931766541812.1250
# Iteration No: 31 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.029625617772507922, 'n_estimators': 800, 'num_leaves': 100}
#
# Score:  503868870794747.3
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 8.3095
# Function value obtained: 503868870794747.3125
# Current minimum: 499931766541812.1250
# Iteration No: 32 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.039267352285750956, 'n_estimators': 800, 'num_leaves': 74}
#
# Score:  502504072375039.7
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 6.6400
# Function value obtained: 502504072375039.6875
# Current minimum: 499931766541812.1250
# Iteration No: 33 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.024705099810930293, 'n_estimators': 800, 'num_leaves': 82}
#
# Score:  504489059868441.6
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 7.5767
# Function value obtained: 504489059868441.6250
# Current minimum: 499931766541812.1250
# Iteration No: 34 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.060146083421393826, 'n_estimators': 636, 'num_leaves': 56}
#
# Score:  502229204259786.4
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 4.6717
# Function value obtained: 502229204259786.3750
# Current minimum: 499931766541812.1250
# Iteration No: 35 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0840849794782298, 'n_estimators': 240, 'num_leaves': 100}
#
# Score:  506929588528217.8
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 3.1479
# Function value obtained: 506929588528217.8125
# Current minimum: 499931766541812.1250
# Iteration No: 36 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.05184788265874773, 'n_estimators': 800, 'num_leaves': 44}
#
# Score:  500314695907210.2
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 4.9405
# Function value obtained: 500314695907210.1875
# Current minimum: 499931766541812.1250
# Iteration No: 37 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.05965187119270711, 'n_estimators': 800, 'num_leaves': 40}
#
# Score:  501426992444536.5
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 4.7713
# Function value obtained: 501426992444536.5000
# Current minimum: 499931766541812.1250
# Iteration No: 38 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.04653154000948202, 'n_estimators': 800, 'num_leaves': 49}
#
# Score:  500823684346652.2
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 5.5150
# Function value obtained: 500823684346652.1875
# Current minimum: 499931766541812.1250
# Iteration No: 39 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.045262371497387044, 'n_estimators': 800, 'num_leaves': 44}
#
# Score:  504249981897556.9
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 5.1667
# Function value obtained: 504249981897556.8750
# Current minimum: 499931766541812.1250
# Iteration No: 40 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.061171580771919094, 'n_estimators': 800, 'num_leaves': 49}
#
# Score:  501822704884500.7
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 5.2167
# Function value obtained: 501822704884500.6875
# Current minimum: 499931766541812.1250
# Iteration No: 41 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07725290641659226, 'n_estimators': 800, 'num_leaves': 36}
#
# Score:  502265152058163.5
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 4.5071
# Function value obtained: 502265152058163.5000
# Current minimum: 499931766541812.1250
# Iteration No: 42 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.06519459884636998, 'n_estimators': 680, 'num_leaves': 43}
#
# Score:  499543565550295.2
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 4.2949
# Function value obtained: 499543565550295.1875
# Current minimum: 499543565550295.1875
# Iteration No: 43 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.06592241594448554, 'n_estimators': 671, 'num_leaves': 41}
#
# Score:  503068473194189.0
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 4.2439
# Function value obtained: 503068473194189.0000
# Current minimum: 499543565550295.1875
# Iteration No: 44 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.06203695775420641, 'n_estimators': 800, 'num_leaves': 51}
#
# Score:  501008561608224.0
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 5.5300
# Function value obtained: 501008561608224.0000
# Current minimum: 499543565550295.1875
# Iteration No: 45 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.13774318759605975, 'n_estimators': 800, 'num_leaves': 26}
#
# Score:  502867235389905.9
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 3.8215
# Function value obtained: 502867235389905.8750
# Current minimum: 499543565550295.1875
# Iteration No: 46 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.09443112311331456, 'n_estimators': 800, 'num_leaves': 38}
#
# Score:  499750717488946.9
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 4.7483
# Function value obtained: 499750717488946.8750
# Current minimum: 499543565550295.1875
# Iteration No: 47 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.09283815540308692, 'n_estimators': 800, 'num_leaves': 39}
#
# Score:  500892933704199.0
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 4.8324
# Function value obtained: 500892933704199.0000
# Current minimum: 499543565550295.1875
# Iteration No: 48 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.09064027451263594, 'n_estimators': 800, 'num_leaves': 32}
#
# Score:  502352153259250.1
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 4.4430
# Function value obtained: 502352153259250.1250
# Current minimum: 499543565550295.1875
# Iteration No: 49 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07792854855384879, 'n_estimators': 800, 'num_leaves': 45}
#
# Score:  499532193373580.8
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 5.4029
# Function value obtained: 499532193373580.8125
# Current minimum: 499532193373580.8125
# Iteration No: 50 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07930001062135084, 'n_estimators': 800, 'num_leaves': 45}
#
# Score:  500377429908658.2
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 5.3499
# Function value obtained: 500377429908658.1875
# Current minimum: 499532193373580.8125
# Iteration No: 51 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.08043455335521361, 'n_estimators': 800, 'num_leaves': 45}
#
# Score:  500293712097196.7
#
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 5.4059
# Function value obtained: 500293712097196.6875
# Current minimum: 499532193373580.8125
# Iteration No: 52 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.10449440289934304, 'n_estimators': 800, 'num_leaves': 40}
#
# Score:  501473974475358.1
#
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 5.0806
# Function value obtained: 501473974475358.1250
# Current minimum: 499532193373580.8125
# Iteration No: 53 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0670440502496635, 'n_estimators': 800, 'num_leaves': 50}
#
# Score:  501010501244485.6
#
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 5.8193
# Function value obtained: 501010501244485.6250
# Current minimum: 499532193373580.8125
# Iteration No: 54 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0553903731646972, 'n_estimators': 800, 'num_leaves': 57}
#
# Score:  500518010762361.9
#
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 6.2877
# Function value obtained: 500518010762361.8750
# Current minimum: 499532193373580.8125
# Iteration No: 55 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.04378988919564279, 'n_estimators': 800, 'num_leaves': 87}
#
# Score:  501856475665658.8
#
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 8.3866
# Function value obtained: 501856475665658.8125
# Current minimum: 499532193373580.8125
# Iteration No: 56 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.2759739142986628, 'n_estimators': 800, 'num_leaves': 10}
#
# Score:  525075421622038.4
#
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 3.2139
# Function value obtained: 525075421622038.3750
# Current minimum: 499532193373580.8125
# Iteration No: 57 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07472361881238061, 'n_estimators': 800, 'num_leaves': 47}
#
# Score:  502298608865422.6
#
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 5.5811
# Function value obtained: 502298608865422.6250
# Current minimum: 499532193373580.8125
# Iteration No: 58 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0494647174827344, 'n_estimators': 800, 'num_leaves': 61}
#
# Score:  500851735289696.5
#
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 6.5470
# Function value obtained: 500851735289696.5000
# Current minimum: 499532193373580.8125
# Iteration No: 59 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.11889404512083941, 'n_estimators': 800, 'num_leaves': 38}
#
# Score:  502059790571493.4
#
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 4.8864
# Function value obtained: 502059790571493.3750
# Current minimum: 499532193373580.8125
# Iteration No: 60 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.049613314890329115, 'n_estimators': 800, 'num_leaves': 60}
#
# Score:  502274784051022.8
#
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 6.5730
# Function value obtained: 502274784051022.8125
# Current minimum: 499532193373580.8125
# Iteration No: 61 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0956641662444852, 'n_estimators': 706, 'num_leaves': 38}
#
# Score:  501825769689934.9
#
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 4.4551
# Function value obtained: 501825769689934.8750
# Current minimum: 499532193373580.8125
# Iteration No: 62 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.042415528180218154, 'n_estimators': 800, 'num_leaves': 100}
#
# Score:  500377689405841.4
#
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 9.1393
# Function value obtained: 500377689405841.3750
# Current minimum: 499532193373580.8125
# Iteration No: 63 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.04360824694754629, 'n_estimators': 800, 'num_leaves': 100}
#
# Score:  501647406431244.7
#
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 9.3855
# Function value obtained: 501647406431244.6875
# Current minimum: 499532193373580.8125
# Iteration No: 64 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.042579857364918317, 'n_estimators': 800, 'num_leaves': 89}
#
# Score:  499278429028484.6
#
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 8.6909
# Function value obtained: 499278429028484.6250
# Current minimum: 499278429028484.6250
# Iteration No: 65 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0512510676762394, 'n_estimators': 800, 'num_leaves': 87}
#
# Score:  502703054079244.0
#
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 7.7350
# Function value obtained: 502703054079244.0000
# Current minimum: 499278429028484.6250
# Iteration No: 66 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.08512537639278343, 'n_estimators': 100, 'num_leaves': 100}
#
# Score:  522391970840019.5
#
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 1.8657
# Function value obtained: 522391970840019.5000
# Current minimum: 499278429028484.6250
# Iteration No: 67 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.01, 'n_estimators': 800, 'num_leaves': 51}
#
# Score:  529399363627027.7
#
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 6.2266
# Function value obtained: 529399363627027.6875
# Current minimum: 499278429028484.6250
# Iteration No: 68 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.09011341965668569, 'n_estimators': 800, 'num_leaves': 54}
#
# Score:  501162569140045.9
#
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 5.7392
# Function value obtained: 501162569140045.8750
# Current minimum: 499278429028484.6250
# Iteration No: 69 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07516409930282285, 'n_estimators': 800, 'num_leaves': 10}
#
# Score:  524000905565877.8
#
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 3.0418
# Function value obtained: 524000905565877.8125
# Current minimum: 499278429028484.6250
# Iteration No: 70 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.14137930068318225, 'n_estimators': 800, 'num_leaves': 39}
#
# Score:  509972599436592.5
#
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 4.6941
# Function value obtained: 509972599436592.5000
# Current minimum: 499278429028484.6250
# Iteration No: 71 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.10077072108888388, 'n_estimators': 425, 'num_leaves': 100}
#
# Score:  508187000784972.5
#
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 5.1597
# Function value obtained: 508187000784972.5000
# Current minimum: 499278429028484.6250
# Iteration No: 72 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.01, 'n_estimators': 800, 'num_leaves': 100}
#
# Score:  519909337832105.7
#
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 9.1013
# Function value obtained: 519909337832105.6875
# Current minimum: 499278429028484.6250
# Iteration No: 73 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07326250005523417, 'n_estimators': 728, 'num_leaves': 47}
#
# Score:  500972495171495.0
#
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 4.9695
# Function value obtained: 500972495171495.0000
# Current minimum: 499278429028484.6250
# Iteration No: 74 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.03818829822066033, 'n_estimators': 800, 'num_leaves': 100}
#
# Score:  505785087493136.4
#
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 8.5767
# Function value obtained: 505785087493136.3750
# Current minimum: 499278429028484.6250
# Iteration No: 75 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07525387674962414, 'n_estimators': 401, 'num_leaves': 86}
#
# Score:  505253455017268.2
#
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 4.5922
# Function value obtained: 505253455017268.1875
# Current minimum: 499278429028484.6250
# Iteration No: 76 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07041315830613097, 'n_estimators': 800, 'num_leaves': 47}
#
# Score:  500499054587699.8
#
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 5.4249
# Function value obtained: 500499054587699.8125
# Current minimum: 499278429028484.6250
# Iteration No: 77 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07051379997525538, 'n_estimators': 800, 'num_leaves': 47}
#
# Score:  502129223919738.1
#
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 5.5410
# Function value obtained: 502129223919738.1250
# Current minimum: 499278429028484.6250
# Iteration No: 78 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.05283442946972263, 'n_estimators': 800, 'num_leaves': 74}
#
# Score:  500825277948028.6
#
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 7.1024
# Function value obtained: 500825277948028.6250
# Current minimum: 499278429028484.6250
# Iteration No: 79 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.061986335065858315, 'n_estimators': 800, 'num_leaves': 69}
#
# Score:  500144882006807.2
#
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 6.7121
# Function value obtained: 500144882006807.1875
# Current minimum: 499278429028484.6250
# Iteration No: 80 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.04271890393592813, 'n_estimators': 800, 'num_leaves': 79}
#
# Score:  500779436033761.1
#
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 7.3317
# Function value obtained: 500779436033761.1250
# Current minimum: 499278429028484.6250
# Iteration No: 81 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.06461922842210531, 'n_estimators': 800, 'num_leaves': 81}
#
# Score:  501976912850947.4
#
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 7.4888
# Function value obtained: 501976912850947.3750
# Current minimum: 499278429028484.6250
# Iteration No: 82 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.054152416930445924, 'n_estimators': 682, 'num_leaves': 73}
#
# Score:  502740106352266.8
#
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 6.4959
# Function value obtained: 502740106352266.8125
# Current minimum: 499278429028484.6250
# Iteration No: 83 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0633388752017321, 'n_estimators': 800, 'num_leaves': 59}
#
# Score:  499739614729291.5
#
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 6.4088
# Function value obtained: 499739614729291.5000
# Current minimum: 499278429028484.6250
# Iteration No: 84 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.06342353388415502, 'n_estimators': 800, 'num_leaves': 59}
#
# Score:  498278127354936.7
#
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 6.2187
# Function value obtained: 498278127354936.6875
# Current minimum: 498278127354936.6875
# Iteration No: 85 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07844332823609058, 'n_estimators': 800, 'num_leaves': 100}
#
# Score:  505046749366591.7
#
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 8.7159
# Function value obtained: 505046749366591.6875
# Current minimum: 498278127354936.6875
# Iteration No: 86 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07974265173860265, 'n_estimators': 800, 'num_leaves': 68}
#
# Score:  500494139496325.9
#
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 6.5910
# Function value obtained: 500494139496325.8750
# Current minimum: 498278127354936.6875
# Iteration No: 87 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.08265083825674216, 'n_estimators': 800, 'num_leaves': 72}
#
# Score:  501380417735764.6
#
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 6.9443
# Function value obtained: 501380417735764.6250
# Current minimum: 498278127354936.6875
# Iteration No: 88 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.11503431440320049, 'n_estimators': 652, 'num_leaves': 32}
#
# Score:  504346999629285.6
#
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 3.8670
# Function value obtained: 504346999629285.6250
# Current minimum: 498278127354936.6875
# Iteration No: 89 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07598062048195553, 'n_estimators': 710, 'num_leaves': 59}
#
# Score:  500626478869329.8
#
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 5.6291
# Function value obtained: 500626478869329.8125
# Current minimum: 498278127354936.6875
# Iteration No: 90 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.06991443527988228, 'n_estimators': 800, 'num_leaves': 62}
#
# Score:  499891079494762.9
#
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 6.2627
# Function value obtained: 499891079494762.8750
# Current minimum: 498278127354936.6875
# Iteration No: 91 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07035696246818866, 'n_estimators': 800, 'num_leaves': 62}
#
# Score:  498033875107780.2
#
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 6.3237
# Function value obtained: 498033875107780.1875
# Current minimum: 498033875107780.1875
# Iteration No: 92 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0824736155716551, 'n_estimators': 661, 'num_leaves': 74}
#
# Score:  502484257441721.8
#
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 6.0525
# Function value obtained: 502484257441721.8125
# Current minimum: 498033875107780.1875
# Iteration No: 93 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.09276555438156735, 'n_estimators': 800, 'num_leaves': 78}
#
# Score:  503727469924070.2
#
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 7.3867
# Function value obtained: 503727469924070.1875
# Current minimum: 498033875107780.1875
# Iteration No: 94 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.027564421947615866, 'n_estimators': 800, 'num_leaves': 61}
#
# Score:  504721006016567.5
#
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 6.6280
# Function value obtained: 504721006016567.5000
# Current minimum: 498033875107780.1875
# Iteration No: 95 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.07954985155130297, 'n_estimators': 710, 'num_leaves': 56}
#
# Score:  503757016153066.1
#
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 5.4940
# Function value obtained: 503757016153066.1250
# Current minimum: 498033875107780.1875
# Iteration No: 96 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.0593672884643262, 'n_estimators': 800, 'num_leaves': 67}
#
# Score:  500291189369424.3
#
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 6.7151
# Function value obtained: 500291189369424.3125
# Current minimum: 498033875107780.1875
# Iteration No: 97 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.044434971690163506, 'n_estimators': 584, 'num_leaves': 79}
#
# Score:  501685809713814.7
#
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 6.1136
# Function value obtained: 501685809713814.6875
# Current minimum: 498033875107780.1875
# Iteration No: 98 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.043278038886720605, 'n_estimators': 604, 'num_leaves': 59}
#
# Score:  503259947781352.9
#
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 5.1937
# Function value obtained: 503259947781352.8750
# Current minimum: 498033875107780.1875
# Iteration No: 99 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.10625354416242491, 'n_estimators': 283, 'num_leaves': 83}
#
# Score:  511383459950133.3
#
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 3.5542
# Function value obtained: 511383459950133.3125
# Current minimum: 498033875107780.1875
# Iteration No: 100 started. Searching for the next optimal point.
#
#  {'learning_rate': 0.05933609754527171, 'n_estimators': 800, 'num_leaves': 67}
#
# Score:  499560444234563.6
#
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 7.0714
# Function value obtained: 499560444234563.6250
# Current minimum: 498033875107780.1875
#
#  *** Optimal hyperparameters ***
# learning_rate: 0.07035696246818866
# n_estimators: 800
# num_leaves: 62
# Saved: optimization_data_conductivity.pkl

# %%
# Plot convergence plot
final_stage.convergence_plot()
# Out:
# Saved: Optimisation_result_conductivity.png

# %%
# objective and evaluation plot
final_stage.objective_plot()

# %%
# Train model with optimal hyperparameter identified
final_stage.train_model()
# Out:
# LGBMRegressor(importance_type='gain', learning_rate=0.07035696246818866,
#               n_estimators=800, num_leaves=62, random_state=42)

# %%
# Evaluate model using test set
final_stage.evaluate(
                    strategy = 'weighted', 
                    adjusted = False, 
                    max_value = 9999123921578508,
                    min_value = 0
                    )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pred_target   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                 3.543e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:11:19   Log-Likelihood:            -2.6171e+05
# No. Observations:                7444   AIC:                         5.234e+05
# Df Residuals:                    7442   BIC:                         5.234e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          2.52e-16    1.2e-18    210.163      0.000     2.5e-16    2.54e-16
# conductivity     0.8507      0.004    210.163      0.000       0.843       0.859
# ==============================================================================
# Omnibus:                     2238.985   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           375850.456
# Skew:                           0.079   Prob(JB):                         0.00
# Kurtosis:                      37.810   Cond. No.                     1.39e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
# MAE:  186789253317397.28
# MSE:  2.3885038383092824e+29
# RMSE:  488723218019083.1
# R-squared:  0.8312483824703624
# Max error:  7172625287985475.0
# Explained_variance_score:  0.8312577468538831
# Linear fit has:
# m =  0.8506680138610536
# c =  2.5200182155213404e-16
# Saved: regression_plot_conductivity.png

# %% [markdown]
# ### Final Figure

# %%
import pandas as pd
import numpy as np
import joblib
import statsmodels.api as sm
import matplotlib.pyplot as plt

from matplotlib.gridspec import GridSpec
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, max_error
from sklearn.metrics import explained_variance_score,mean_squared_error

from lightgbm.sklearn import LGBMRegressor

# %%
# Target
target = 'p_conductivity'

# Path
path = 'C:/Users/Songy/OneDrive/Documents/GBSFS4MPP_local/new_properties/6. ricci_boltztrap_mp_tabular (done)/'
path_to_save = path + target + '_results/'

# Features
features = joblib.load(path_to_save + 'features_selected_from_RFE_' + target + '.pkl')
print(len(features))

# Path to training data
df_train = joblib.load(path_to_save + 'df_train_' + target + '_engineered.pkl')
df_test = joblib.load(path_to_save + 'df_test_' + target + '_engineered.pkl')

problem = 'regression'

scaled = False
# Out:
# 53

# %%
lgbm = LGBMRegressor(
                    boosting_type ='gbdt',
                    objective=problem,
                    importance_type='gain',
                    learning_rate=0.07035696246818866,
                    n_estimators=800,
                    num_leaves=62,
                    max_depth=-1,
                    random_state=42
                    )

lgbm.fit(df_train[features], df_train[target].values.ravel())
lgbm
# Out:
# LGBMRegressor(importance_type='gain', learning_rate=0.07035696246818866,
#               n_estimators=800, num_leaves=62, objective='regression',
#               random_state=42)

# %%
# Predict
predicted_target = lgbm.predict(df_test[features])

# Generate table of results
id_index = df_test.index.tolist()

df_pred = pd.DataFrame({'task_id': id_index,
                        'act_target': df_test[target].values.reshape(1, -1).ravel(),
                        'pred_target': predicted_target
                        })

# Eliminate zeros (?)
df_pred['adj_pred_target'] = df_pred['pred_target']
df_pred['adj_pred_target'] = df_pred['adj_pred_target'].apply(lambda x: 0 if x < 0 else x)

# Define variables
y_test = df_pred['act_target']
y_pred_adj = df_pred['adj_pred_target']
y_pred = df_pred['pred_target']

# %%
print('Max value:', df_test[target].max())
print('Min value:', df_test[target].min())
# Out:
# Max value: 9855520678802140.0
# Min value: 134061.44346344474

# %%
def plot(df_pred, adj=False):
        # Plot results
        max_value = 9999123921578508
        min_value = 0

        X = df_pred['act_target']
        if adj is True:
                Y = df_pred['adj_pred_target']
        else:
                Y = df_pred['pred_target']

        # Stats
        results = sm.OLS(Y,sm.add_constant(X)).fit()
        print(results.summary())

        # Figure
        fig = plt.figure(figsize=(10, 10), dpi=500) #, dpi=100, facecolor='w', edgecolor='k')
        gs = GridSpec(4, 4)

        ax_scatter = fig.add_subplot(gs[1:4, 0:3])
        ax_hist_y = fig.add_subplot(gs[0,0:3])
        ax_hist_x = fig.add_subplot(gs[1:4, 3])


        fontsize = 18

        # Predicted vs Actual
        ax_scatter.plot(X, Y, 'o', markersize=6, color='black', alpha=0.12)

        offset = 0.15
        # line of best fit
        linear_fit = np.linspace(min_value-offset, max_value-offset, 10)
        ax_scatter.plot(linear_fit, linear_fit*results.params[1] + results.params[0], '-.', color='tab:blue', alpha=0.7)

        # Ideal y=x 
        y = x = np.linspace(min_value-offset, max_value-offset, 10)
        ax_scatter.plot(x, y, '--', color='red', alpha=0.7)

        ticks = np.linspace(min_value, max_value, 5)

        onset = -10000
        ax_scatter.set_xlabel('DFT Calculation of p-type Electronic \n Thermal Conductivity (W/K/m/s)', fontsize=fontsize)
        ax_scatter.set_ylabel('ML Prediction of p-type Electronic \n Thermal Conductivity (W/K/m/s)', fontsize=fontsize)
        ax_scatter.tick_params(axis='both', which='both', labelsize=fontsize, direction="in")
        ax_scatter.set_xlim(min_value-onset, max_value+onset)
        ax_scatter.set_ylim(min_value-onset, max_value+onset)
        ax_scatter.set_xticks(ticks)
        ax_scatter.set_yticks(ticks)
        
        plt.setp(ax_scatter.get_yticklabels()[0], visible=False)
        
        #ax_scatter.autoscale(True)

        ax_hist_x.tick_params(axis='both', which='both', labelsize=fontsize, direction="in", labelleft=False)
        ax_hist_x.set_xlabel('Count', fontsize=fontsize)
        ax_hist_x.set_ylim(min_value-onset, max_value+onset)
        ax_hist_x.set_xticks([0, 2500, 5000])
        ax_hist_x.set_yticks(ticks)

        ax_hist_y.tick_params(axis='both', which='both', labelsize=fontsize, direction="in", labelbottom=False)
        ax_hist_y.set_ylabel('Count', fontsize=fontsize)
        ax_hist_y.set_xlim(min_value-onset, max_value+onset)
        ax_hist_y.set_yticks([0, 2000, 4000])
        ax_hist_y.set_xticks(ticks)

        # Distribution plots
        alpha = 0.4
        histtype = 'bar' #'step' bar
        color = 'black' #'tab:grey'
        bins = 60 #70

        ax_hist_y.hist(
                        y_pred_adj, 
                        bins=bins, 
                        color=color, 
                        histtype=histtype,
                        alpha=alpha
                        )
        ax_hist_x.hist(
                        y_test, 
                        orientation='horizontal', 
                        bins=bins, 
                        color=color, 
                        histtype=histtype,
                        alpha=alpha
                        )


        #Text in figure
        font1 = {'family': 'DejaVu Sans',
                'color':  'red',
                'weight': 'normal',
                'size': fontsize-3,
                }

        font2 = {'family': 'DejaVu Sans',
                'color':  'tab:blue',
                'weight': 'normal',
                'size': fontsize-3,
                }

        font3 = {'family': 'DejaVu Sans', #'serif',
                'color':  'black',
                'weight': 'normal',
                'size': fontsize-3,
                }

        ax_scatter.text(5e15, 6.5e15, r'$y = x$', fontdict=font1)
        ax_scatter.text(6.8e15, 5.3e15, r'$y = ' + str(round(results.params[1],1)) + 'x - ' + str(round(results.params[0],1)) + '$', fontdict=font2)

        
        x = 4.5e15
        y = 0.25e15
        
        r2 = r2_score(X, Y)
        ax_scatter.text(x, y + 0.9e15, r'$R^{2}$ = ' + str(round(r2,2)), fontdict=font3)

        mae = mean_absolute_error(X, Y)
        ax_scatter.text(x, y + 0.5e15, r'$MAE$ = ' + str('{:.2e}'.format(round(mae,2))) + ' (W/K/m/s)', fontdict=font3)

        mse = mean_squared_error(X, Y, squared=False)
        ax_scatter.text(x, y, r'$RMSE$ = ' + str('{:.2e}'.format(round(mse,2))) + ' (W/K/m/s)', fontdict=font3)

        #final_figure
        #fig.savefig('final_regression_mag_v1.png', dpi = 500, bbox_inches="tight")

        plt.show()

        print('m = ', results.params[1])
        print('c = ', results.params[0], '\n')

        print('MAE: ', mean_absolute_error(X, Y))
        print('MSE: ', mean_squared_error(X, Y))
        print('RMSE: ', mean_squared_error(X, Y, squared=False))
        print('R-squared: ', r2_score(X, Y))
        print('Max error: ', max_error(X, Y))
        print('Explained_variance_score: ', explained_variance_score(X, Y, multioutput='variance_weighted'))

# %%
plot(df_pred, adj=True)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        adj_pred_target   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                 4.658e+04
# Date:                Sat, 27 Aug 2022   Prob (F-statistic):               0.00
# Time:                        10:51:24   Log-Likelihood:            -3.3313e+05
# No. Observations:                9514   AIC:                         6.663e+05
# Df Residuals:                    9512   BIC:                         6.663e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.678e-16   1.13e-18    237.395      0.000    2.66e-16     2.7e-16
# act_target     0.8514      0.004    237.395      0.000       0.844       0.858
# ==============================================================================
# Omnibus:                     5090.252   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1200687.605
# Skew:                           1.416   Prob(JB):                         0.00
# Kurtosis:                      57.962   Cond. No.                     1.19e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.19e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
# m =  0.8513570259028043
# c =  2.6784499294368857e-16
#
# MAE:  151650096257263.44
# MSE:  1.7904874487844e+29
# RMSE:  423141518736273.4
# R-squared:  0.8353692172481733
# Max error:  7523560144814676.0
# Explained_variance_score:  0.8353896992120837

# %%
import seaborn as sns

# Generate feature ranking
model = lgbm

feature_score = pd.DataFrame({'feature': features, 'relevance_score': model.feature_importances_})
feature_score = feature_score.sort_values(by = 'relevance_score', ascending = False)
feature_score = feature_score.reset_index(drop = True)

#Plot data of feature relevance 
sns.set(rc = {'figure.figsize':(10, 10)})
sns.set_style("whitegrid")

# Number of features to plot
no_of_features = 30

fig = sns.barplot(x = 'relevance_score', y = 'feature', data = feature_score[:no_of_features])
fig.set(xlabel = 'Relevance score', ylabel = 'Feature')

# plt.savefig('feature_relevance_plot_experimental_bayesian_scaffold_split_v2.png', dpi = 300)
# Out:
# [Text(0.5, 0, 'Relevance score'), Text(0, 0.5, 'Feature')]
